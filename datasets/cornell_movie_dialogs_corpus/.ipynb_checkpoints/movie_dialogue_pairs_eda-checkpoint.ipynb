# %% [markdown]
# # Exploratory Data Analysis
#
# Having processed our movie data, we'll proceed to explore our data. To do this, the following dependencies would be loaded. Pandas for organize our data, nltk for NLP, matplotlib and seaborn for plotting, and itertools and collections to assist in data structuring.

# %%
# Importing dependencies
import pandas as pd
import nltk
import itertools
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from nltk.probability import FreqDist
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
# Loading processed file from our data cleaning process
file = 'processed_movie_dialogues.csv'
df = pd.read_csv(file)

# %%
df
# Out:
#         Unnamed: 0                                            Comment  \
# 0                0  can we make this quick roxanne korrine and and...
# 1                1  well i thought we would start with pronunciati...
# 2                2  not the hacking and gagging and spitting part ...
# 3                3  you are asking me out that is so cute what is ...
# 4                4  no no it is my fault we did not have a proper ...
# ...            ...                                                ...
# 221611      221611                             your orders mr vereker
# 221612      221612  i am to take the sikali with the main column t...
# 221613      221613  lord chelmsford seems to want me to stay back ...
# 221614      221614  well i assure you sir i have no desire to crea...
# 221615      221615  and i assure you you do not in fact i would be...
#
#                                                     Reply  Comment Length  \
# 0       well i thought we would start with pronunciati...              21
# 1       not the hacking and gagging and spitting part ...              14
# 2       okay then how about we try out some french cui...               9
# 3                                               forget it              14
# 4                                                 cameron              16
# ...                                                   ...             ...
# 221611  i am to take the sikali with the main column t...               4
# 221612  lord chelmsford seems to want me to stay back ...              13
# 221613  i think chelmsford wants a good man on the bor...              12
# 221614  and i assure you you do not in fact i would be...              13
# 221615  so far only their scouts but we have had repor...              22
#
#         Reply Length
# 0                 14
# 1                  9
# 2                 12
# 3                  2
# 4                  1
# ...              ...
# 221611            13
# 221612            12
# 221613            23
# 221614            22
# 221615            18
#
# [221616 rows x 5 columns]

# %%
# Dropping extraneous column from the DataFrame
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df
# Out:
#                                                   Comment  \
# 0       can we make this quick roxanne korrine and and...
# 1       well i thought we would start with pronunciati...
# 2       not the hacking and gagging and spitting part ...
# 3       you are asking me out that is so cute what is ...
# 4       no no it is my fault we did not have a proper ...
# ...                                                   ...
# 221611                             your orders mr vereker
# 221612  i am to take the sikali with the main column t...
# 221613  lord chelmsford seems to want me to stay back ...
# 221614  well i assure you sir i have no desire to crea...
# 221615  and i assure you you do not in fact i would be...
#
#                                                     Reply  Comment Length  \
# 0       well i thought we would start with pronunciati...              21
# 1       not the hacking and gagging and spitting part ...              14
# 2       okay then how about we try out some french cui...               9
# 3                                               forget it              14
# 4                                                 cameron              16
# ...                                                   ...             ...
# 221611  i am to take the sikali with the main column t...               4
# 221612  lord chelmsford seems to want me to stay back ...              13
# 221613  i think chelmsford wants a good man on the bor...              12
# 221614  and i assure you you do not in fact i would be...              13
# 221615  so far only their scouts but we have had repor...              22
#
#         Reply Length
# 0                 14
# 1                  9
# 2                 12
# 3                  2
# 4                  1
# ...              ...
# 221611            13
# 221612            12
# 221613            23
# 221614            22
# 221615            18
#
# [221616 rows x 4 columns]

# %%
# Checking data types in DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221616 entries, 0 to 221615
# Data columns (total 4 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Comment         221610 non-null  object
#  1   Reply           221613 non-null  object
#  2   Comment Length  221616 non-null  int64
#  3   Reply Length    221616 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 6.8+ MB

# %%
df[df['Comment'].isna() == True]
# Out:
#        Comment                                              Reply  \
# 36363      NaN                                                NaN
# 36580      NaN                         newer more powerful design
# 87489      NaN                                               what
# 87514      NaN  i do not believe this i do not bloody believe ...
# 87651      NaN  virginity right mother poverty chastity and ig...
# 151966     NaN                                it has a broken leg
#
#         Comment Length  Reply Length
# 36363                1             1
# 36580                1             4
# 87489                1             1
# 87514                1            11
# 87651                1            14
# 151966               1             5

# %%
df[df['Reply'].isna() == True]
# Out:
#                          Comment Reply  Comment Length  Reply Length
# 36363                        NaN   NaN               1             1
# 36579                     pem115   NaN               1             1
# 87488  agnes who mother superior   NaN               4             1

# %% [markdown]
# There seems to be stray NaNs in our dataset. In our case, we'll remove them as they are not proper (comment, reply) responses.

# %%
# Dropping NaNs from dataset
df = df.drop(df[df['Comment'].isna()].index)
df = df.drop(df[df['Reply'].isna()].index)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 221608 entries, 0 to 221615
# Data columns (total 4 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Comment         221608 non-null  object
#  1   Reply           221608 non-null  object
#  2   Comment Length  221608 non-null  int64
#  3   Reply Length    221608 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 8.5+ MB

# %% [markdown]
# Before utilizing the full capacity of NLTK for NLP, we'll first explore the frequency of repsonses.

# %%
# Checking the frequency of comments using NLTK's FreqDist() function
fdist_common_comments = FreqDist(df['Comment'])
fdist_common_comments.most_common(20)
# Out:
# [('what', 1732),
#  ('yes', 1383),
#  ('no', 1303),
#  ('yeah', 1030),
#  ('why', 526),
#  ('i do not know', 304),
#  ('hello', 260),
#  ('who', 254),
#  ('why not', 226),
#  ('oh', 214),
#  ('what is it', 214),
#  ('what do you mean', 213),
#  ('what is that', 208),
#  ('none', 205),
#  ('okay', 203),
#  ('huh', 198),
#  ('what are you doing', 195),
#  ('really', 189),
#  ('hi', 187),
#  ('thank you', 184)]

# %%
# Checking the frequency of replies using NLTK's FreqDist() function
fdist_common_replies = FreqDist(df['Reply'])
fdist_common_replies.most_common(20)
# Out:
# [('what', 1600),
#  ('yes', 1540),
#  ('no', 1496),
#  ('yeah', 1170),
#  ('why', 512),
#  ('i do not know', 408),
#  ('okay', 377),
#  ('oh', 293),
#  ('sure', 285),
#  ('thank you', 250),
#  ('who', 248),
#  ('yes sir', 243),
#  ('why not', 242),
#  ('i know', 231),
#  ('right', 213),
#  ('huh', 212),
#  ('none', 211),
#  ('really', 208),
#  ('what do you mean', 208),
#  ('thanks', 186)]

# %%
# Plotting the top 20 responses for both comments and replies
fig1, ax1 = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
x_comment = dict(fdist_common_comments.most_common(20)).keys()
y_comment_count = dict(fdist_common_comments.most_common(20)).values()
x_reply = dict(fdist_common_replies.most_common(20)).keys()
y_reply_count = dict(fdist_common_replies.most_common(20)).values()
ax1[0].bar(x_comment, y_comment_count)
ax1[0].tick_params('x', rotation = 90)
ax1[0].set_title('Comments')
ax1[1].bar(x_reply, y_reply_count)
ax1[1].tick_params('x', rotation = 90)
ax1[1].set_title('Replies')
ax1[0].set_ylabel('Count')
fig1.suptitle('Response Count')
plt.show()

# %% [markdown]
# In order for us to use the data later on for training and testing, the responses needs to be broken down into tokens. For this, we will utilize NLTK's word tokenizer, the word_tokenize() function.

# %%
# Tokenizing Text using NLTK's word tokenizer
df['Tokenized Comment'] = df['Comment'].apply(word_tokenize)
df['Tokenized Reply'] = df['Reply'].apply(word_tokenize)
df
# Out:
#                                                   Comment  \
# 0       can we make this quick roxanne korrine and and...
# 1       well i thought we would start with pronunciati...
# 2       not the hacking and gagging and spitting part ...
# 3       you are asking me out that is so cute what is ...
# 4       no no it is my fault we did not have a proper ...
# ...                                                   ...
# 221611                             your orders mr vereker
# 221612  i am to take the sikali with the main column t...
# 221613  lord chelmsford seems to want me to stay back ...
# 221614  well i assure you sir i have no desire to crea...
# 221615  and i assure you you do not in fact i would be...
#
#                                                     Reply  Comment Length  \
# 0       well i thought we would start with pronunciati...              21
# 1       not the hacking and gagging and spitting part ...              14
# 2       okay then how about we try out some french cui...               9
# 3                                               forget it              14
# 4                                                 cameron              16
# ...                                                   ...             ...
# 221611  i am to take the sikali with the main column t...               4
# 221612  lord chelmsford seems to want me to stay back ...              13
# 221613  i think chelmsford wants a good man on the bor...              12
# 221614  and i assure you you do not in fact i would be...              13
# 221615  so far only their scouts but we have had repor...              22
#
#         Reply Length                                  Tokenized Comment  \
# 0                 14  [can, we, make, this, quick, roxanne, korrine,...
# 1                  9  [well, i, thought, we, would, start, with, pro...
# 2                 12  [not, the, hacking, and, gagging, and, spittin...
# 3                  2  [you, are, asking, me, out, that, is, so, cute...
# 4                  1  [no, no, it, is, my, fault, we, did, not, have...
# ...              ...                                                ...
# 221611            13                        [your, orders, mr, vereker]
# 221612            12  [i, am, to, take, the, sikali, with, the, main...
# 221613            23  [lord, chelmsford, seems, to, want, me, to, st...
# 221614            22  [well, i, assure, you, sir, i, have, no, desir...
# 221615            18  [and, i, assure, you, you, do, not, in, fact, ...
#
#                                           Tokenized Reply
# 0       [well, i, thought, we, would, start, with, pro...
# 1       [not, the, hacking, and, gagging, and, spittin...
# 2       [okay, then, how, about, we, try, out, some, f...
# 3                                            [forget, it]
# 4                                               [cameron]
# ...                                                   ...
# 221611  [i, am, to, take, the, sikali, with, the, main...
# 221612  [lord, chelmsford, seems, to, want, me, to, st...
# 221613  [i, think, chelmsford, wants, a, good, man, on...
# 221614  [and, i, assure, you, you, do, not, in, fact, ...
# 221615  [so, far, only, their, scouts, but, we, have, ...
#
# [221608 rows x 6 columns]

# %% [markdown]
# We could check the frequency of individual words after being tokenized.

# %%
# Taking the lists from DataFrame and flattening it into one list
all_words_comments = list(itertools.chain.from_iterable(df['Tokenized Comment'][:]))
all_words_replies = list(itertools.chain.from_iterable(df['Tokenized Reply'][:]))

# %%
fdist_common_comment_words = FreqDist(all_words_comments)
fdist_common_comment_words.most_common(20)
# Out:
# [('you', 108941),
#  ('i', 97821),
#  ('the', 69651),
#  ('to', 62192),
#  ('is', 56827),
#  ('a', 49795),
#  ('not', 48650),
#  ('it', 45483),
#  ('do', 33384),
#  ('that', 32974),
#  ('and', 31546),
#  ('what', 29413),
#  ('are', 28534),
#  ('of', 27761),
#  ('have', 24481),
#  ('in', 23959),
#  ('me', 22851),
#  ('we', 20060),
#  ('he', 19055),
#  ('am', 17745)]

# %%
fdist_common_reply_words = FreqDist(all_words_replies)
fdist_common_reply_words.most_common(20)
# Out:
# [('i', 106565),
#  ('you', 105424),
#  ('the', 71232),
#  ('to', 63975),
#  ('is', 57691),
#  ('not', 52849),
#  ('a', 52425),
#  ('it', 49212),
#  ('that', 34530),
#  ('do', 34331),
#  ('and', 34292),
#  ('of', 29087),
#  ('are', 27017),
#  ('what', 25759),
#  ('in', 24984),
#  ('have', 24873),
#  ('me', 23849),
#  ('we', 20405),
#  ('he', 20396),
#  ('am', 19459)]

# %%
# Plotting the top 20 words for both comments and replies
fig2, ax2 = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
x_comment_word = dict(fdist_common_comment_words.most_common(20)).keys()
y_comment_word_count = dict(fdist_common_comment_words.most_common(20)).values()
x_reply_word = dict(fdist_common_reply_words.most_common(20)).keys()
y_reply_word_count = dict(fdist_common_reply_words.most_common(20)).values()
ax2[0].bar(x_comment_word, y_comment_word_count)
ax2[0].tick_params('x', rotation = 90)
ax2[0].set_title('Comments')
ax2[1].bar(x_reply_word, y_reply_word_count)
ax2[1].tick_params('x', rotation = 90)
ax2[1].set_title('Replies')
ax2[0].set_ylabel('Count')
fig2.suptitle('Word Count')
plt.show()

# %% [markdown]
# While stop words are useful when carrying out a conversation, the words themselves carry very little information, thus for NLP, English stop words are removed. Here, we'll do so using the stop words stored in NLTK's stopwords.words().

# %%
# Defining function to remove stop words from our dataset
stop_words = set(stopwords.words("english"))
def remove_stopwords(text):
    return [i for i in text if i not in stop_words]

# %%
# Removing stop words
df['Filtered Comment'] = df['Tokenized Comment'].apply(remove_stopwords)
df['Filtered Reply'] = df['Tokenized Reply'].apply(remove_stopwords)
df
# Out:
#                                                   Comment  \
# 0       can we make this quick roxanne korrine and and...
# 1       well i thought we would start with pronunciati...
# 2       not the hacking and gagging and spitting part ...
# 3       you are asking me out that is so cute what is ...
# 4       no no it is my fault we did not have a proper ...
# ...                                                   ...
# 221611                             your orders mr vereker
# 221612  i am to take the sikali with the main column t...
# 221613  lord chelmsford seems to want me to stay back ...
# 221614  well i assure you sir i have no desire to crea...
# 221615  and i assure you you do not in fact i would be...
#
#                                                     Reply  Comment Length  \
# 0       well i thought we would start with pronunciati...              21
# 1       not the hacking and gagging and spitting part ...              14
# 2       okay then how about we try out some french cui...               9
# 3                                               forget it              14
# 4                                                 cameron              16
# ...                                                   ...             ...
# 221611  i am to take the sikali with the main column t...               4
# 221612  lord chelmsford seems to want me to stay back ...              13
# 221613  i think chelmsford wants a good man on the bor...              12
# 221614  and i assure you you do not in fact i would be...              13
# 221615  so far only their scouts but we have had repor...              22
#
#         Reply Length                                  Tokenized Comment  \
# 0                 14  [can, we, make, this, quick, roxanne, korrine,...
# 1                  9  [well, i, thought, we, would, start, with, pro...
# 2                 12  [not, the, hacking, and, gagging, and, spittin...
# 3                  2  [you, are, asking, me, out, that, is, so, cute...
# 4                  1  [no, no, it, is, my, fault, we, did, not, have...
# ...              ...                                                ...
# 221611            13                        [your, orders, mr, vereker]
# 221612            12  [i, am, to, take, the, sikali, with, the, main...
# 221613            23  [lord, chelmsford, seems, to, want, me, to, st...
# 221614            22  [well, i, assure, you, sir, i, have, no, desir...
# 221615            18  [and, i, assure, you, you, do, not, in, fact, ...
#
#                                           Tokenized Reply  \
# 0       [well, i, thought, we, would, start, with, pro...
# 1       [not, the, hacking, and, gagging, and, spittin...
# 2       [okay, then, how, about, we, try, out, some, f...
# 3                                            [forget, it]
# 4                                               [cameron]
# ...                                                   ...
# 221611  [i, am, to, take, the, sikali, with, the, main...
# 221612  [lord, chelmsford, seems, to, want, me, to, st...
# 221613  [i, think, chelmsford, wants, a, good, man, on...
# 221614  [and, i, assure, you, you, do, not, in, fact, ...
# 221615  [so, far, only, their, scouts, but, we, have, ...
#
#                                          Filtered Comment  \
# 0       [make, quick, roxanne, korrine, andrew, barret...
# 1       [well, thought, would, start, pronunciation, o...
# 2              [hacking, gagging, spitting, part, please]
# 3                                    [asking, cute, name]
# 4                           [fault, proper, introduction]
# ...                                                   ...
# 221611                              [orders, mr, vereker]
# 221612                [take, sikali, main, column, river]
# 221613  [lord, chelmsford, seems, want, stay, back, ba...
# 221614  [well, assure, sir, desire, create, difficulti...
# 221615  [assure, fact, would, obliged, best, advice, s...
#
#                                            Filtered Reply
# 0       [well, thought, would, start, pronunciation, o...
# 1              [hacking, gagging, spitting, part, please]
# 2           [okay, try, french, cuisine, saturday, night]
# 3                                                [forget]
# 4                                               [cameron]
# ...                                                   ...
# 221611                [take, sikali, main, column, river]
# 221612  [lord, chelmsford, seems, want, stay, back, ba...
# 221613  [think, chelmsford, wants, good, man, border, ...
# 221614  [assure, fact, would, obliged, best, advice, s...
# 221615  [far, scouts, reports, small, impi, farther, n...
#
# [221608 rows x 8 columns]

# %%
all_words_comments_no_stop = list(itertools.chain.from_iterable(df['Filtered Comment'][:]))
all_words_replies_no_stop = list(itertools.chain.from_iterable(df['Filtered Reply'][:]))

# %%
fdist_common_comment_words_no_stop = FreqDist(all_words_comments_no_stop)
fdist_common_comment_words_no_stop.most_common(20)
# Out:
# [('know', 15415),
#  ('like', 10714),
#  ('would', 10528),
#  ('get', 9630),
#  ('going', 9500),
#  ('got', 9313),
#  ('want', 8742),
#  ('think', 7769),
#  ('one', 7142),
#  ('go', 6786),
#  ('well', 6660),
#  ('right', 6544),
#  ('see', 5608),
#  ('us', 5500),
#  ('oh', 5278),
#  ('could', 5215),
#  ('yes', 5064),
#  ('tell', 4937),
#  ('good', 4883),
#  ('yeah', 4588)]

# %%
fdist_common_reply_words_no_stop = FreqDist(all_words_replies_no_stop)
fdist_common_reply_words_no_stop.most_common(20)
# Out:
# [('know', 16528),
#  ('like', 10997),
#  ('would', 10874),
#  ('get', 10272),
#  ('got', 9588),
#  ('going', 9071),
#  ('want', 8888),
#  ('think', 7927),
#  ('well', 7646),
#  ('one', 7571),
#  ('right', 7511),
#  ('go', 7091),
#  ('yes', 6335),
#  ('yeah', 5957),
#  ('see', 5916),
#  ('oh', 5911),
#  ('us', 5827),
#  ('good', 5348),
#  ('could', 5294),
#  ('tell', 4962)]

# %%
# Plotting the top 20 words for both comments and replies after removing stop words
fig3, ax3 = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
x_comment_word_no_stop = dict(fdist_common_comment_words_no_stop.most_common(20)).keys()
y_comment_word_count_no_stop = dict(fdist_common_comment_words_no_stop.most_common(20)).values()
x_reply_word_no_stop = dict(fdist_common_reply_words_no_stop.most_common(20)).keys()
y_reply_word_count_no_stop = dict(fdist_common_reply_words_no_stop.most_common(20)).values()
ax3[0].bar(x_comment_word_no_stop, y_comment_word_count_no_stop)
ax3[0].tick_params('x', rotation = 90)
ax3[0].set_title('Comments')
ax3[1].bar(x_reply_word_no_stop, y_reply_word_count_no_stop)
ax3[1].tick_params('x', rotation = 90)
ax3[1].set_title('Replies')
ax3[0].set_ylabel('Count')
fig3.suptitle('Word Count without Stop Words')
plt.show()

# %% [markdown]
# To further process our dataset, we will lemmatize the words into their root form using NLTK's WordNet Lemmatizer. Before that, we will tag the words using parts of speech labels (POS). These POS tags will then be converted into a format the lemmatizer could read and use.

# %%
# Tagging our words with parts of speed
df['Filtered Comment with tag'] = df['Filtered Comment'].apply(nltk.tag.pos_tag)
df['Filtered Reply with tag'] = df['Filtered Reply'].apply(nltk.tag.pos_tag)
df
# Out:
#                                                   Comment  \
# 0       can we make this quick roxanne korrine and and...
# 1       well i thought we would start with pronunciati...
# 2       not the hacking and gagging and spitting part ...
# 3       you are asking me out that is so cute what is ...
# 4       no no it is my fault we did not have a proper ...
# ...                                                   ...
# 221611                             your orders mr vereker
# 221612  i am to take the sikali with the main column t...
# 221613  lord chelmsford seems to want me to stay back ...
# 221614  well i assure you sir i have no desire to crea...
# 221615  and i assure you you do not in fact i would be...
#
#                                                     Reply  Comment Length  \
# 0       well i thought we would start with pronunciati...              21
# 1       not the hacking and gagging and spitting part ...              14
# 2       okay then how about we try out some french cui...               9
# 3                                               forget it              14
# 4                                                 cameron              16
# ...                                                   ...             ...
# 221611  i am to take the sikali with the main column t...               4
# 221612  lord chelmsford seems to want me to stay back ...              13
# 221613  i think chelmsford wants a good man on the bor...              12
# 221614  and i assure you you do not in fact i would be...              13
# 221615  so far only their scouts but we have had repor...              22
#
#         Reply Length                                  Tokenized Comment  \
# 0                 14  [can, we, make, this, quick, roxanne, korrine,...
# 1                  9  [well, i, thought, we, would, start, with, pro...
# 2                 12  [not, the, hacking, and, gagging, and, spittin...
# 3                  2  [you, are, asking, me, out, that, is, so, cute...
# 4                  1  [no, no, it, is, my, fault, we, did, not, have...
# ...              ...                                                ...
# 221611            13                        [your, orders, mr, vereker]
# 221612            12  [i, am, to, take, the, sikali, with, the, main...
# 221613            23  [lord, chelmsford, seems, to, want, me, to, st...
# 221614            22  [well, i, assure, you, sir, i, have, no, desir...
# 221615            18  [and, i, assure, you, you, do, not, in, fact, ...
#
#                                           Tokenized Reply  \
# 0       [well, i, thought, we, would, start, with, pro...
# 1       [not, the, hacking, and, gagging, and, spittin...
# 2       [okay, then, how, about, we, try, out, some, f...
# 3                                            [forget, it]
# 4                                               [cameron]
# ...                                                   ...
# 221611  [i, am, to, take, the, sikali, with, the, main...
# 221612  [lord, chelmsford, seems, to, want, me, to, st...
# 221613  [i, think, chelmsford, wants, a, good, man, on...
# 221614  [and, i, assure, you, you, do, not, in, fact, ...
# 221615  [so, far, only, their, scouts, but, we, have, ...
#
#                                          Filtered Comment  \
# 0       [make, quick, roxanne, korrine, andrew, barret...
# 1       [well, thought, would, start, pronunciation, o...
# 2              [hacking, gagging, spitting, part, please]
# 3                                    [asking, cute, name]
# 4                           [fault, proper, introduction]
# ...                                                   ...
# 221611                              [orders, mr, vereker]
# 221612                [take, sikali, main, column, river]
# 221613  [lord, chelmsford, seems, want, stay, back, ba...
# 221614  [well, assure, sir, desire, create, difficulti...
# 221615  [assure, fact, would, obliged, best, advice, s...
#
#                                            Filtered Reply  \
# 0       [well, thought, would, start, pronunciation, o...
# 1              [hacking, gagging, spitting, part, please]
# 2           [okay, try, french, cuisine, saturday, night]
# 3                                                [forget]
# 4                                               [cameron]
# ...                                                   ...
# 221611                [take, sikali, main, column, river]
# 221612  [lord, chelmsford, seems, want, stay, back, ba...
# 221613  [think, chelmsford, wants, good, man, border, ...
# 221614  [assure, fact, would, obliged, best, advice, s...
# 221615  [far, scouts, reports, small, impi, farther, n...
#
#                                 Filtered Comment with tag  \
# 0       [(make, VB), (quick, JJ), (roxanne, NN), (korr...
# 1       [(well, RB), (thought, RB), (would, MD), (star...
# 2       [(hacking, VBG), (gagging, VBG), (spitting, VB...
# 3                 [(asking, VBG), (cute, NN), (name, NN)]
# 4         [(fault, NN), (proper, JJ), (introduction, NN)]
# ...                                                   ...
# 221611          [(orders, NNS), (mr, VBP), (vereker, NN)]
# 221612  [(take, VB), (sikali, NN), (main, JJ), (column...
# 221613  [(lord, NN), (chelmsford, NN), (seems, VBZ), (...
# 221614  [(well, RB), (assure, NN), (sir, NN), (desire,...
# 221615  [(assure, NN), (fact, NN), (would, MD), (oblig...
#
#                                   Filtered Reply with tag
# 0       [(well, RB), (thought, RB), (would, MD), (star...
# 1       [(hacking, VBG), (gagging, VBG), (spitting, VB...
# 2       [(okay, JJ), (try, NN), (french, JJ), (cuisine...
# 3                                          [(forget, NN)]
# 4                                         [(cameron, NN)]
# ...                                                   ...
# 221611  [(take, VB), (sikali, NN), (main, JJ), (column...
# 221612  [(lord, NN), (chelmsford, NN), (seems, VBZ), (...
# 221613  [(think, NN), (chelmsford, NN), (wants, VBZ), ...
# 221614  [(assure, NN), (fact, NN), (would, MD), (oblig...
# 221615  [(far, RB), (scouts, NNS), (reports, NNS), (sm...
#
# [221608 rows x 10 columns]

# %%
# Defining function to convert our POS tags into WordNet format
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
# Convert tags into WordNet POS format
df['Filtered Comment with WordNet'] = df['Filtered Comment with tag'].apply(lambda x: [(word, get_wordnet_pos(pos_tag)) for (word, pos_tag) in x])
df['Filtered Reply with WordNet'] = df['Filtered Reply with tag'].apply(lambda x: [(word, get_wordnet_pos(pos_tag)) for (word, pos_tag) in x])
df
# Out:
#                                                   Comment  \
# 0       can we make this quick roxanne korrine and and...
# 1       well i thought we would start with pronunciati...
# 2       not the hacking and gagging and spitting part ...
# 3       you are asking me out that is so cute what is ...
# 4       no no it is my fault we did not have a proper ...
# ...                                                   ...
# 221611                             your orders mr vereker
# 221612  i am to take the sikali with the main column t...
# 221613  lord chelmsford seems to want me to stay back ...
# 221614  well i assure you sir i have no desire to crea...
# 221615  and i assure you you do not in fact i would be...
#
#                                                     Reply  Comment Length  \
# 0       well i thought we would start with pronunciati...              21
# 1       not the hacking and gagging and spitting part ...              14
# 2       okay then how about we try out some french cui...               9
# 3                                               forget it              14
# 4                                                 cameron              16
# ...                                                   ...             ...
# 221611  i am to take the sikali with the main column t...               4
# 221612  lord chelmsford seems to want me to stay back ...              13
# 221613  i think chelmsford wants a good man on the bor...              12
# 221614  and i assure you you do not in fact i would be...              13
# 221615  so far only their scouts but we have had repor...              22
#
#         Reply Length                                  Tokenized Comment  \
# 0                 14  [can, we, make, this, quick, roxanne, korrine,...
# 1                  9  [well, i, thought, we, would, start, with, pro...
# 2                 12  [not, the, hacking, and, gagging, and, spittin...
# 3                  2  [you, are, asking, me, out, that, is, so, cute...
# 4                  1  [no, no, it, is, my, fault, we, did, not, have...
# ...              ...                                                ...
# 221611            13                        [your, orders, mr, vereker]
# 221612            12  [i, am, to, take, the, sikali, with, the, main...
# 221613            23  [lord, chelmsford, seems, to, want, me, to, st...
# 221614            22  [well, i, assure, you, sir, i, have, no, desir...
# 221615            18  [and, i, assure, you, you, do, not, in, fact, ...
#
#                                           Tokenized Reply  \
# 0       [well, i, thought, we, would, start, with, pro...
# 1       [not, the, hacking, and, gagging, and, spittin...
# 2       [okay, then, how, about, we, try, out, some, f...
# 3                                            [forget, it]
# 4                                               [cameron]
# ...                                                   ...
# 221611  [i, am, to, take, the, sikali, with, the, main...
# 221612  [lord, chelmsford, seems, to, want, me, to, st...
# 221613  [i, think, chelmsford, wants, a, good, man, on...
# 221614  [and, i, assure, you, you, do, not, in, fact, ...
# 221615  [so, far, only, their, scouts, but, we, have, ...
#
#                                          Filtered Comment  \
# 0       [make, quick, roxanne, korrine, andrew, barret...
# 1       [well, thought, would, start, pronunciation, o...
# 2              [hacking, gagging, spitting, part, please]
# 3                                    [asking, cute, name]
# 4                           [fault, proper, introduction]
# ...                                                   ...
# 221611                              [orders, mr, vereker]
# 221612                [take, sikali, main, column, river]
# 221613  [lord, chelmsford, seems, want, stay, back, ba...
# 221614  [well, assure, sir, desire, create, difficulti...
# 221615  [assure, fact, would, obliged, best, advice, s...
#
#                                            Filtered Reply  \
# 0       [well, thought, would, start, pronunciation, o...
# 1              [hacking, gagging, spitting, part, please]
# 2           [okay, try, french, cuisine, saturday, night]
# 3                                                [forget]
# 4                                               [cameron]
# ...                                                   ...
# 221611                [take, sikali, main, column, river]
# 221612  [lord, chelmsford, seems, want, stay, back, ba...
# 221613  [think, chelmsford, wants, good, man, border, ...
# 221614  [assure, fact, would, obliged, best, advice, s...
# 221615  [far, scouts, reports, small, impi, farther, n...
#
#                                 Filtered Comment with tag  \
# 0       [(make, VB), (quick, JJ), (roxanne, NN), (korr...
# 1       [(well, RB), (thought, RB), (would, MD), (star...
# 2       [(hacking, VBG), (gagging, VBG), (spitting, VB...
# 3                 [(asking, VBG), (cute, NN), (name, NN)]
# 4         [(fault, NN), (proper, JJ), (introduction, NN)]
# ...                                                   ...
# 221611          [(orders, NNS), (mr, VBP), (vereker, NN)]
# 221612  [(take, VB), (sikali, NN), (main, JJ), (column...
# 221613  [(lord, NN), (chelmsford, NN), (seems, VBZ), (...
# 221614  [(well, RB), (assure, NN), (sir, NN), (desire,...
# 221615  [(assure, NN), (fact, NN), (would, MD), (oblig...
#
#                                   Filtered Reply with tag  \
# 0       [(well, RB), (thought, RB), (would, MD), (star...
# 1       [(hacking, VBG), (gagging, VBG), (spitting, VB...
# 2       [(okay, JJ), (try, NN), (french, JJ), (cuisine...
# 3                                          [(forget, NN)]
# 4                                         [(cameron, NN)]
# ...                                                   ...
# 221611  [(take, VB), (sikali, NN), (main, JJ), (column...
# 221612  [(lord, NN), (chelmsford, NN), (seems, VBZ), (...
# 221613  [(think, NN), (chelmsford, NN), (wants, VBZ), ...
# 221614  [(assure, NN), (fact, NN), (would, MD), (oblig...
# 221615  [(far, RB), (scouts, NNS), (reports, NNS), (sm...
#
#                             Filtered Comment with WordNet  \
# 0       [(make, v), (quick, a), (roxanne, n), (korrine...
# 1       [(well, r), (thought, r), (would, n), (start, ...
# 2       [(hacking, v), (gagging, v), (spitting, v), (p...
# 3                     [(asking, v), (cute, n), (name, n)]
# 4            [(fault, n), (proper, a), (introduction, n)]
# ...                                                   ...
# 221611               [(orders, n), (mr, v), (vereker, n)]
# 221612  [(take, v), (sikali, n), (main, a), (column, n...
# 221613  [(lord, n), (chelmsford, n), (seems, v), (want...
# 221614  [(well, r), (assure, n), (sir, n), (desire, n)...
# 221615  [(assure, n), (fact, n), (would, n), (obliged,...
#
#                               Filtered Reply with WordNet
# 0       [(well, r), (thought, r), (would, n), (start, ...
# 1       [(hacking, v), (gagging, v), (spitting, v), (p...
# 2       [(okay, a), (try, n), (french, a), (cuisine, n...
# 3                                           [(forget, n)]
# 4                                          [(cameron, n)]
# ...                                                   ...
# 221611  [(take, v), (sikali, n), (main, a), (column, n...
# 221612  [(lord, n), (chelmsford, n), (seems, v), (want...
# 221613  [(think, n), (chelmsford, n), (wants, v), (goo...
# 221614  [(assure, n), (fact, n), (would, n), (obliged,...
# 221615  [(far, r), (scouts, n), (reports, n), (small, ...
#
# [221608 rows x 12 columns]

# %%
# Lemmatize our tagged comments and replies
wordnet_lemmatizer = WordNetLemmatizer()
df['Lemmatized Comment'] = df['Filtered Comment with WordNet'].apply(lambda x: [wordnet_lemmatizer.lemmatize(word, tag) for (word, tag) in x])
df['Lemmatized Reply'] = df['Filtered Reply with WordNet'].apply(lambda x: [wordnet_lemmatizer.lemmatize(word, tag) for (word, tag) in x])
df
# Out:
#                                                   Comment  \
# 0       can we make this quick roxanne korrine and and...
# 1       well i thought we would start with pronunciati...
# 2       not the hacking and gagging and spitting part ...
# 3       you are asking me out that is so cute what is ...
# 4       no no it is my fault we did not have a proper ...
# ...                                                   ...
# 221611                             your orders mr vereker
# 221612  i am to take the sikali with the main column t...
# 221613  lord chelmsford seems to want me to stay back ...
# 221614  well i assure you sir i have no desire to crea...
# 221615  and i assure you you do not in fact i would be...
#
#                                                     Reply  Comment Length  \
# 0       well i thought we would start with pronunciati...              21
# 1       not the hacking and gagging and spitting part ...              14
# 2       okay then how about we try out some french cui...               9
# 3                                               forget it              14
# 4                                                 cameron              16
# ...                                                   ...             ...
# 221611  i am to take the sikali with the main column t...               4
# 221612  lord chelmsford seems to want me to stay back ...              13
# 221613  i think chelmsford wants a good man on the bor...              12
# 221614  and i assure you you do not in fact i would be...              13
# 221615  so far only their scouts but we have had repor...              22
#
#         Reply Length                                  Tokenized Comment  \
# 0                 14  [can, we, make, this, quick, roxanne, korrine,...
# 1                  9  [well, i, thought, we, would, start, with, pro...
# 2                 12  [not, the, hacking, and, gagging, and, spittin...
# 3                  2  [you, are, asking, me, out, that, is, so, cute...
# 4                  1  [no, no, it, is, my, fault, we, did, not, have...
# ...              ...                                                ...
# 221611            13                        [your, orders, mr, vereker]
# 221612            12  [i, am, to, take, the, sikali, with, the, main...
# 221613            23  [lord, chelmsford, seems, to, want, me, to, st...
# 221614            22  [well, i, assure, you, sir, i, have, no, desir...
# 221615            18  [and, i, assure, you, you, do, not, in, fact, ...
#
#                                           Tokenized Reply  \
# 0       [well, i, thought, we, would, start, with, pro...
# 1       [not, the, hacking, and, gagging, and, spittin...
# 2       [okay, then, how, about, we, try, out, some, f...
# 3                                            [forget, it]
# 4                                               [cameron]
# ...                                                   ...
# 221611  [i, am, to, take, the, sikali, with, the, main...
# 221612  [lord, chelmsford, seems, to, want, me, to, st...
# 221613  [i, think, chelmsford, wants, a, good, man, on...
# 221614  [and, i, assure, you, you, do, not, in, fact, ...
# 221615  [so, far, only, their, scouts, but, we, have, ...
#
#                                          Filtered Comment  \
# 0       [make, quick, roxanne, korrine, andrew, barret...
# 1       [well, thought, would, start, pronunciation, o...
# 2              [hacking, gagging, spitting, part, please]
# 3                                    [asking, cute, name]
# 4                           [fault, proper, introduction]
# ...                                                   ...
# 221611                              [orders, mr, vereker]
# 221612                [take, sikali, main, column, river]
# 221613  [lord, chelmsford, seems, want, stay, back, ba...
# 221614  [well, assure, sir, desire, create, difficulti...
# 221615  [assure, fact, would, obliged, best, advice, s...
#
#                                            Filtered Reply  \
# 0       [well, thought, would, start, pronunciation, o...
# 1              [hacking, gagging, spitting, part, please]
# 2           [okay, try, french, cuisine, saturday, night]
# 3                                                [forget]
# 4                                               [cameron]
# ...                                                   ...
# 221611                [take, sikali, main, column, river]
# 221612  [lord, chelmsford, seems, want, stay, back, ba...
# 221613  [think, chelmsford, wants, good, man, border, ...
# 221614  [assure, fact, would, obliged, best, advice, s...
# 221615  [far, scouts, reports, small, impi, farther, n...
#
#                                 Filtered Comment with tag  \
# 0       [(make, VB), (quick, JJ), (roxanne, NN), (korr...
# 1       [(well, RB), (thought, RB), (would, MD), (star...
# 2       [(hacking, VBG), (gagging, VBG), (spitting, VB...
# 3                 [(asking, VBG), (cute, NN), (name, NN)]
# 4         [(fault, NN), (proper, JJ), (introduction, NN)]
# ...                                                   ...
# 221611          [(orders, NNS), (mr, VBP), (vereker, NN)]
# 221612  [(take, VB), (sikali, NN), (main, JJ), (column...
# 221613  [(lord, NN), (chelmsford, NN), (seems, VBZ), (...
# 221614  [(well, RB), (assure, NN), (sir, NN), (desire,...
# 221615  [(assure, NN), (fact, NN), (would, MD), (oblig...
#
#                                   Filtered Reply with tag  \
# 0       [(well, RB), (thought, RB), (would, MD), (star...
# 1       [(hacking, VBG), (gagging, VBG), (spitting, VB...
# 2       [(okay, JJ), (try, NN), (french, JJ), (cuisine...
# 3                                          [(forget, NN)]
# 4                                         [(cameron, NN)]
# ...                                                   ...
# 221611  [(take, VB), (sikali, NN), (main, JJ), (column...
# 221612  [(lord, NN), (chelmsford, NN), (seems, VBZ), (...
# 221613  [(think, NN), (chelmsford, NN), (wants, VBZ), ...
# 221614  [(assure, NN), (fact, NN), (would, MD), (oblig...
# 221615  [(far, RB), (scouts, NNS), (reports, NNS), (sm...
#
#                             Filtered Comment with WordNet  \
# 0       [(make, v), (quick, a), (roxanne, n), (korrine...
# 1       [(well, r), (thought, r), (would, n), (start, ...
# 2       [(hacking, v), (gagging, v), (spitting, v), (p...
# 3                     [(asking, v), (cute, n), (name, n)]
# 4            [(fault, n), (proper, a), (introduction, n)]
# ...                                                   ...
# 221611               [(orders, n), (mr, v), (vereker, n)]
# 221612  [(take, v), (sikali, n), (main, a), (column, n...
# 221613  [(lord, n), (chelmsford, n), (seems, v), (want...
# 221614  [(well, r), (assure, n), (sir, n), (desire, n)...
# 221615  [(assure, n), (fact, n), (would, n), (obliged,...
#
#                               Filtered Reply with WordNet  \
# 0       [(well, r), (thought, r), (would, n), (start, ...
# 1       [(hacking, v), (gagging, v), (spitting, v), (p...
# 2       [(okay, a), (try, n), (french, a), (cuisine, n...
# 3                                           [(forget, n)]
# 4                                          [(cameron, n)]
# ...                                                   ...
# 221611  [(take, v), (sikali, n), (main, a), (column, n...
# 221612  [(lord, n), (chelmsford, n), (seems, v), (want...
# 221613  [(think, n), (chelmsford, n), (wants, v), (goo...
# 221614  [(assure, n), (fact, n), (would, n), (obliged,...
# 221615  [(far, r), (scouts, n), (reports, n), (small, ...
#
#                                        Lemmatized Comment  \
# 0       [make, quick, roxanne, korrine, andrew, barret...
# 1       [well, thought, would, start, pronunciation, o...
# 2                         [hack, gag, spit, part, please]
# 3                                       [ask, cute, name]
# 4                           [fault, proper, introduction]
# ...                                                   ...
# 221611                               [order, mr, vereker]
# 221612                [take, sikali, main, column, river]
# 221613  [lord, chelmsford, seem, want, stay, back, bas...
# 221614  [well, assure, sir, desire, create, difficulty...
# 221615  [assure, fact, would, oblige, best, advice, sc...
#
#                                          Lemmatized Reply
# 0       [well, thought, would, start, pronunciation, o...
# 1                         [hack, gag, spit, part, please]
# 2           [okay, try, french, cuisine, saturday, night]
# 3                                                [forget]
# 4                                               [cameron]
# ...                                                   ...
# 221611                [take, sikali, main, column, river]
# 221612  [lord, chelmsford, seem, want, stay, back, bas...
# 221613  [think, chelmsford, want, good, man, border, f...
# 221614  [assure, fact, would, oblige, best, advice, sc...
# 221615      [far, scout, report, small, impi, far, north]
#
# [221608 rows x 14 columns]

# %% [markdown]
# We could check on it the frequency of the data again now that everything has been lemmatized.

# %%
all_words_comments_lemmatized = list(itertools.chain.from_iterable(df['Lemmatized Comment'][:]))
all_words_replies_lemmatized = list(itertools.chain.from_iterable(df['Lemmatized Reply'][:]))

# %%
fdist_common_comment_words_lemmatized = FreqDist(all_words_comments_lemmatized)
fdist_common_comment_words_lemmatized.most_common(20)
# Out:
# [('get', 20547),
#  ('go', 18676),
#  ('know', 17111),
#  ('like', 11119),
#  ('want', 10721),
#  ('would', 10528),
#  ('think', 10173),
#  ('say', 9213),
#  ('well', 7764),
#  ('one', 7547),
#  ('come', 7295),
#  ('tell', 7108),
#  ('see', 7001),
#  ('right', 6618),
#  ('look', 5996),
#  ('take', 5778),
#  ('make', 5766),
#  ('u', 5513),
#  ('good', 5383),
#  ('oh', 5278)]

# %%
fdist_common_reply_words_lemmatized = FreqDist(all_words_replies_lemmatized)
fdist_common_reply_words_lemmatized.most_common(20)
# Out:
# [('get', 21377),
#  ('go', 18515),
#  ('know', 18381),
#  ('like', 11402),
#  ('want', 10952),
#  ('would', 10874),
#  ('think', 10329),
#  ('say', 9333),
#  ('well', 8919),
#  ('one', 8002),
#  ('right', 7594),
#  ('come', 7492),
#  ('see', 7331),
#  ('tell', 7156),
#  ('yes', 6341),
#  ('take', 6101),
#  ('look', 6098),
#  ('make', 6098),
#  ('yeah', 5957),
#  ('good', 5936)]

# %%
# Plotting the top 20 words for both comments and replies after lemmatizing
fig4, ax4 = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
x_comment_word_lemmatized = dict(fdist_common_comment_words_lemmatized.most_common(20)).keys()
y_comment_word_count_lemmatized = dict(fdist_common_comment_words_lemmatized.most_common(20)).values()
x_reply_word_lemmatized = dict(fdist_common_reply_words_lemmatized.most_common(20)).keys()
y_reply_word_count_lemmatized = dict(fdist_common_reply_words_lemmatized.most_common(20)).values()
ax4[0].bar(x_comment_word_lemmatized, y_comment_word_count_lemmatized)
ax4[0].tick_params('x', rotation = 90)
ax4[0].set_title('Comments')
ax4[1].bar(x_reply_word_lemmatized, y_reply_word_count_lemmatized)
ax4[1].tick_params('x', rotation = 90)
ax4[1].set_title('Replies')
ax4[0].set_ylabel('Count')
fig4.suptitle('Word Count Lemmatized')
plt.show()

# %% [markdown]
# The letter 'u' appears pretty often in the comments (5513 times), which is strange. What is going on? Apparently there an issue with NLTK's wordnet lemmatizer (see link: https://stackoverflow.com/questions/54784287/nltk-wordnetlemmatizer-processes-us-as-u). To deal with the 'u'/'us' issue, we will use an if/else statment for the word 'us'.

# %%
# Lemmatize our tagged comments and replies (an if statement is used for the word 'us')
df['Lemmatized Comment New'] = df['Filtered Comment with WordNet'].apply(lambda x: [wordnet_lemmatizer.lemmatize(word, tag) if word != 'us' else word for (word, tag) in x])
df['Lemmatized Reply New'] = df['Filtered Reply with WordNet'].apply(lambda x: [wordnet_lemmatizer.lemmatize(word, tag) if word != 'us' else word for (word, tag) in x])

# %%
all_words_comments_lemmatized2 = list(itertools.chain.from_iterable(df['Lemmatized Comment New'][:]))
all_words_replies_lemmatized2 = list(itertools.chain.from_iterable(df['Lemmatized Reply New'][:]))

# %%
fdist_common_comment_words_lemmatized2 = FreqDist(all_words_comments_lemmatized2)
fdist_common_comment_words_lemmatized2.most_common(20)
# Out:
# [('get', 20547),
#  ('go', 18676),
#  ('know', 17111),
#  ('like', 11119),
#  ('want', 10721),
#  ('would', 10528),
#  ('think', 10173),
#  ('say', 9213),
#  ('well', 7764),
#  ('one', 7547),
#  ('come', 7295),
#  ('tell', 7108),
#  ('see', 7001),
#  ('right', 6618),
#  ('look', 5996),
#  ('take', 5778),
#  ('make', 5766),
#  ('us', 5507),
#  ('good', 5383),
#  ('oh', 5278)]

# %%
fdist_common_reply_words_lemmatized2 = FreqDist(all_words_replies_lemmatized2)
fdist_common_reply_words_lemmatized2.most_common(20)
# Out:
# [('get', 21377),
#  ('go', 18515),
#  ('know', 18381),
#  ('like', 11402),
#  ('want', 10952),
#  ('would', 10874),
#  ('think', 10329),
#  ('say', 9333),
#  ('well', 8919),
#  ('one', 8002),
#  ('right', 7594),
#  ('come', 7492),
#  ('see', 7331),
#  ('tell', 7156),
#  ('yes', 6341),
#  ('take', 6101),
#  ('look', 6098),
#  ('make', 6098),
#  ('yeah', 5957),
#  ('good', 5936)]

# %%
# Plotting the top 20 words for both comments and replies after lemmatizing
fig5, ax5 = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
x_comment_word_lemmatized2 = dict(fdist_common_comment_words_lemmatized2.most_common(20)).keys()
y_comment_word_count_lemmatized2 = dict(fdist_common_comment_words_lemmatized2.most_common(20)).values()
x_reply_word_lemmatized2 = dict(fdist_common_reply_words_lemmatized2.most_common(20)).keys()
y_reply_word_count_lemmatized2 = dict(fdist_common_reply_words_lemmatized2.most_common(20)).values()
ax5[0].bar(x_comment_word_lemmatized2, y_comment_word_count_lemmatized2)
ax5[0].tick_params('x', rotation = 90)
ax5[0].set_title('Comments')
ax5[1].bar(x_reply_word_lemmatized2, y_reply_word_count_lemmatized2)
ax5[1].tick_params('x', rotation = 90)
ax5[1].set_title('Replies')
ax5[0].set_ylabel('Count')
fig5.suptitle('Word Count Lemmatized')
plt.show()

# %% [markdown]
# The if/else does appear to have fixed most, if not all, of the problems (5507 out of 5513). Either the remaining 6 are actual words (used in the context of a pseudonym like 'U') or it's part of a different problem during lemmatization. We'll leave this alone for now given that it is mostly fixed.
#
# Given we have processed and removed so many words, we should check to see if there are any empty comments and replies. Before that however, we'll tidy up our DataFrame. The new columns will replace the old lemmatized columns.

# %%
df = df.drop(['Lemmatized Comment', 'Lemmatized Reply'], axis=1)

# %%
df['Processed Comment Length'] = df['Lemmatized Comment New'].apply(len)
df['Processed Reply Length'] = df['Lemmatized Reply New'].apply(len)
df = df.rename({'Lemmatized Comment New':'Lemmatized Comment', 'Lemmatized Reply New':'Lemmatized Reply'}, axis=1)
df
# Out:
#                                                   Comment  \
# 0       can we make this quick roxanne korrine and and...
# 1       well i thought we would start with pronunciati...
# 2       not the hacking and gagging and spitting part ...
# 3       you are asking me out that is so cute what is ...
# 4       no no it is my fault we did not have a proper ...
# ...                                                   ...
# 221611                             your orders mr vereker
# 221612  i am to take the sikali with the main column t...
# 221613  lord chelmsford seems to want me to stay back ...
# 221614  well i assure you sir i have no desire to crea...
# 221615  and i assure you you do not in fact i would be...
#
#                                                     Reply  Comment Length  \
# 0       well i thought we would start with pronunciati...              21
# 1       not the hacking and gagging and spitting part ...              14
# 2       okay then how about we try out some french cui...               9
# 3                                               forget it              14
# 4                                                 cameron              16
# ...                                                   ...             ...
# 221611  i am to take the sikali with the main column t...               4
# 221612  lord chelmsford seems to want me to stay back ...              13
# 221613  i think chelmsford wants a good man on the bor...              12
# 221614  and i assure you you do not in fact i would be...              13
# 221615  so far only their scouts but we have had repor...              22
#
#         Reply Length                                  Tokenized Comment  \
# 0                 14  [can, we, make, this, quick, roxanne, korrine,...
# 1                  9  [well, i, thought, we, would, start, with, pro...
# 2                 12  [not, the, hacking, and, gagging, and, spittin...
# 3                  2  [you, are, asking, me, out, that, is, so, cute...
# 4                  1  [no, no, it, is, my, fault, we, did, not, have...
# ...              ...                                                ...
# 221611            13                        [your, orders, mr, vereker]
# 221612            12  [i, am, to, take, the, sikali, with, the, main...
# 221613            23  [lord, chelmsford, seems, to, want, me, to, st...
# 221614            22  [well, i, assure, you, sir, i, have, no, desir...
# 221615            18  [and, i, assure, you, you, do, not, in, fact, ...
#
#                                           Tokenized Reply  \
# 0       [well, i, thought, we, would, start, with, pro...
# 1       [not, the, hacking, and, gagging, and, spittin...
# 2       [okay, then, how, about, we, try, out, some, f...
# 3                                            [forget, it]
# 4                                               [cameron]
# ...                                                   ...
# 221611  [i, am, to, take, the, sikali, with, the, main...
# 221612  [lord, chelmsford, seems, to, want, me, to, st...
# 221613  [i, think, chelmsford, wants, a, good, man, on...
# 221614  [and, i, assure, you, you, do, not, in, fact, ...
# 221615  [so, far, only, their, scouts, but, we, have, ...
#
#                                          Filtered Comment  \
# 0       [make, quick, roxanne, korrine, andrew, barret...
# 1       [well, thought, would, start, pronunciation, o...
# 2              [hacking, gagging, spitting, part, please]
# 3                                    [asking, cute, name]
# 4                           [fault, proper, introduction]
# ...                                                   ...
# 221611                              [orders, mr, vereker]
# 221612                [take, sikali, main, column, river]
# 221613  [lord, chelmsford, seems, want, stay, back, ba...
# 221614  [well, assure, sir, desire, create, difficulti...
# 221615  [assure, fact, would, obliged, best, advice, s...
#
#                                            Filtered Reply  \
# 0       [well, thought, would, start, pronunciation, o...
# 1              [hacking, gagging, spitting, part, please]
# 2           [okay, try, french, cuisine, saturday, night]
# 3                                                [forget]
# 4                                               [cameron]
# ...                                                   ...
# 221611                [take, sikali, main, column, river]
# 221612  [lord, chelmsford, seems, want, stay, back, ba...
# 221613  [think, chelmsford, wants, good, man, border, ...
# 221614  [assure, fact, would, obliged, best, advice, s...
# 221615  [far, scouts, reports, small, impi, farther, n...
#
#                                 Filtered Comment with tag  \
# 0       [(make, VB), (quick, JJ), (roxanne, NN), (korr...
# 1       [(well, RB), (thought, RB), (would, MD), (star...
# 2       [(hacking, VBG), (gagging, VBG), (spitting, VB...
# 3                 [(asking, VBG), (cute, NN), (name, NN)]
# 4         [(fault, NN), (proper, JJ), (introduction, NN)]
# ...                                                   ...
# 221611          [(orders, NNS), (mr, VBP), (vereker, NN)]
# 221612  [(take, VB), (sikali, NN), (main, JJ), (column...
# 221613  [(lord, NN), (chelmsford, NN), (seems, VBZ), (...
# 221614  [(well, RB), (assure, NN), (sir, NN), (desire,...
# 221615  [(assure, NN), (fact, NN), (would, MD), (oblig...
#
#                                   Filtered Reply with tag  \
# 0       [(well, RB), (thought, RB), (would, MD), (star...
# 1       [(hacking, VBG), (gagging, VBG), (spitting, VB...
# 2       [(okay, JJ), (try, NN), (french, JJ), (cuisine...
# 3                                          [(forget, NN)]
# 4                                         [(cameron, NN)]
# ...                                                   ...
# 221611  [(take, VB), (sikali, NN), (main, JJ), (column...
# 221612  [(lord, NN), (chelmsford, NN), (seems, VBZ), (...
# 221613  [(think, NN), (chelmsford, NN), (wants, VBZ), ...
# 221614  [(assure, NN), (fact, NN), (would, MD), (oblig...
# 221615  [(far, RB), (scouts, NNS), (reports, NNS), (sm...
#
#                             Filtered Comment with WordNet  \
# 0       [(make, v), (quick, a), (roxanne, n), (korrine...
# 1       [(well, r), (thought, r), (would, n), (start, ...
# 2       [(hacking, v), (gagging, v), (spitting, v), (p...
# 3                     [(asking, v), (cute, n), (name, n)]
# 4            [(fault, n), (proper, a), (introduction, n)]
# ...                                                   ...
# 221611               [(orders, n), (mr, v), (vereker, n)]
# 221612  [(take, v), (sikali, n), (main, a), (column, n...
# 221613  [(lord, n), (chelmsford, n), (seems, v), (want...
# 221614  [(well, r), (assure, n), (sir, n), (desire, n)...
# 221615  [(assure, n), (fact, n), (would, n), (obliged,...
#
#                               Filtered Reply with WordNet  \
# 0       [(well, r), (thought, r), (would, n), (start, ...
# 1       [(hacking, v), (gagging, v), (spitting, v), (p...
# 2       [(okay, a), (try, n), (french, a), (cuisine, n...
# 3                                           [(forget, n)]
# 4                                          [(cameron, n)]
# ...                                                   ...
# 221611  [(take, v), (sikali, n), (main, a), (column, n...
# 221612  [(lord, n), (chelmsford, n), (seems, v), (want...
# 221613  [(think, n), (chelmsford, n), (wants, v), (goo...
# 221614  [(assure, n), (fact, n), (would, n), (obliged,...
# 221615  [(far, r), (scouts, n), (reports, n), (small, ...
#
#                                        Lemmatized Comment  \
# 0       [make, quick, roxanne, korrine, andrew, barret...
# 1       [well, thought, would, start, pronunciation, o...
# 2                         [hack, gag, spit, part, please]
# 3                                       [ask, cute, name]
# 4                           [fault, proper, introduction]
# ...                                                   ...
# 221611                               [order, mr, vereker]
# 221612                [take, sikali, main, column, river]
# 221613  [lord, chelmsford, seem, want, stay, back, bas...
# 221614  [well, assure, sir, desire, create, difficulty...
# 221615  [assure, fact, would, oblige, best, advice, sc...
#
#                                          Lemmatized Reply  \
# 0       [well, thought, would, start, pronunciation, o...
# 1                         [hack, gag, spit, part, please]
# 2           [okay, try, french, cuisine, saturday, night]
# 3                                                [forget]
# 4                                               [cameron]
# ...                                                   ...
# 221611                [take, sikali, main, column, river]
# 221612  [lord, chelmsford, seem, want, stay, back, bas...
# 221613  [think, chelmsford, want, good, man, border, f...
# 221614  [assure, fact, would, oblige, best, advice, sc...
# 221615      [far, scout, report, small, impi, far, north]
#
#         Processed Comment Length  Processed Reply Length
# 0                             11                       6
# 1                              6                       5
# 2                              5                       6
# 3                              3                       1
# 4                              3                       1
# ...                          ...                     ...
# 221611                         3                       5
# 221612                         5                       7
# 221613                         7                      13
# 221614                         7                       8
# 221615                         8                       7
#
# [221608 rows x 16 columns]

# %%
# Checking the length of processed comments and replies
df[df['Processed Comment Length'] == 0].count()
# Out:
# Comment                          11607
# Reply                            11607
# Comment Length                   11607
# Reply Length                     11607
# Tokenized Comment                11607
# Tokenized Reply                  11607
# Filtered Comment                 11607
# Filtered Reply                   11607
# Filtered Comment with tag        11607
# Filtered Reply with tag          11607
# Filtered Comment with WordNet    11607
# Filtered Reply with WordNet      11607
# Lemmatized Comment               11607
# Lemmatized Reply                 11607
# Processed Comment Length         11607
# Processed Reply Length           11607
# dtype: int64

# %%
df[df['Processed Reply Length'] == 0].count()
# Out:
# Comment                          10871
# Reply                            10871
# Comment Length                   10871
# Reply Length                     10871
# Tokenized Comment                10871
# Tokenized Reply                  10871
# Filtered Comment                 10871
# Filtered Reply                   10871
# Filtered Comment with tag        10871
# Filtered Reply with tag          10871
# Filtered Comment with WordNet    10871
# Filtered Reply with WordNet      10871
# Lemmatized Comment               10871
# Lemmatized Reply                 10871
# Processed Comment Length         10871
# Processed Reply Length           10871
# dtype: int64

# %% [markdown]
# There is quite a bit of empty responses. As we need comments and replies as pairs, the empty responses is of no value to us. We will remove these rows using Pandas' drop() function.

# %%
# Dropping rows with processed comments and replies that ends up empty
df = df.drop(df[df['Processed Comment Length'] == 0].index)
df = df.drop(df[df['Processed Reply Length'] == 0].index)

# %%
df[df['Processed Comment Length'] == 0].count()
# Out:
# Comment                          0
# Reply                            0
# Comment Length                   0
# Reply Length                     0
# Tokenized Comment                0
# Tokenized Reply                  0
# Filtered Comment                 0
# Filtered Reply                   0
# Filtered Comment with tag        0
# Filtered Reply with tag          0
# Filtered Comment with WordNet    0
# Filtered Reply with WordNet      0
# Lemmatized Comment               0
# Lemmatized Reply                 0
# Processed Comment Length         0
# Processed Reply Length           0
# dtype: int64

# %%
df[df['Processed Reply Length'] == 0].count()
# Out:
# Comment                          0
# Reply                            0
# Comment Length                   0
# Reply Length                     0
# Tokenized Comment                0
# Tokenized Reply                  0
# Filtered Comment                 0
# Filtered Reply                   0
# Filtered Comment with tag        0
# Filtered Reply with tag          0
# Filtered Comment with WordNet    0
# Filtered Reply with WordNet      0
# Lemmatized Comment               0
# Lemmatized Reply                 0
# Processed Comment Length         0
# Processed Reply Length           0
# dtype: int64

# %%
df
# Out:
#                                                   Comment  \
# 0       can we make this quick roxanne korrine and and...
# 1       well i thought we would start with pronunciati...
# 2       not the hacking and gagging and spitting part ...
# 3       you are asking me out that is so cute what is ...
# 4       no no it is my fault we did not have a proper ...
# ...                                                   ...
# 221611                             your orders mr vereker
# 221612  i am to take the sikali with the main column t...
# 221613  lord chelmsford seems to want me to stay back ...
# 221614  well i assure you sir i have no desire to crea...
# 221615  and i assure you you do not in fact i would be...
#
#                                                     Reply  Comment Length  \
# 0       well i thought we would start with pronunciati...              21
# 1       not the hacking and gagging and spitting part ...              14
# 2       okay then how about we try out some french cui...               9
# 3                                               forget it              14
# 4                                                 cameron              16
# ...                                                   ...             ...
# 221611  i am to take the sikali with the main column t...               4
# 221612  lord chelmsford seems to want me to stay back ...              13
# 221613  i think chelmsford wants a good man on the bor...              12
# 221614  and i assure you you do not in fact i would be...              13
# 221615  so far only their scouts but we have had repor...              22
#
#         Reply Length                                  Tokenized Comment  \
# 0                 14  [can, we, make, this, quick, roxanne, korrine,...
# 1                  9  [well, i, thought, we, would, start, with, pro...
# 2                 12  [not, the, hacking, and, gagging, and, spittin...
# 3                  2  [you, are, asking, me, out, that, is, so, cute...
# 4                  1  [no, no, it, is, my, fault, we, did, not, have...
# ...              ...                                                ...
# 221611            13                        [your, orders, mr, vereker]
# 221612            12  [i, am, to, take, the, sikali, with, the, main...
# 221613            23  [lord, chelmsford, seems, to, want, me, to, st...
# 221614            22  [well, i, assure, you, sir, i, have, no, desir...
# 221615            18  [and, i, assure, you, you, do, not, in, fact, ...
#
#                                           Tokenized Reply  \
# 0       [well, i, thought, we, would, start, with, pro...
# 1       [not, the, hacking, and, gagging, and, spittin...
# 2       [okay, then, how, about, we, try, out, some, f...
# 3                                            [forget, it]
# 4                                               [cameron]
# ...                                                   ...
# 221611  [i, am, to, take, the, sikali, with, the, main...
# 221612  [lord, chelmsford, seems, to, want, me, to, st...
# 221613  [i, think, chelmsford, wants, a, good, man, on...
# 221614  [and, i, assure, you, you, do, not, in, fact, ...
# 221615  [so, far, only, their, scouts, but, we, have, ...
#
#                                          Filtered Comment  \
# 0       [make, quick, roxanne, korrine, andrew, barret...
# 1       [well, thought, would, start, pronunciation, o...
# 2              [hacking, gagging, spitting, part, please]
# 3                                    [asking, cute, name]
# 4                           [fault, proper, introduction]
# ...                                                   ...
# 221611                              [orders, mr, vereker]
# 221612                [take, sikali, main, column, river]
# 221613  [lord, chelmsford, seems, want, stay, back, ba...
# 221614  [well, assure, sir, desire, create, difficulti...
# 221615  [assure, fact, would, obliged, best, advice, s...
#
#                                            Filtered Reply  \
# 0       [well, thought, would, start, pronunciation, o...
# 1              [hacking, gagging, spitting, part, please]
# 2           [okay, try, french, cuisine, saturday, night]
# 3                                                [forget]
# 4                                               [cameron]
# ...                                                   ...
# 221611                [take, sikali, main, column, river]
# 221612  [lord, chelmsford, seems, want, stay, back, ba...
# 221613  [think, chelmsford, wants, good, man, border, ...
# 221614  [assure, fact, would, obliged, best, advice, s...
# 221615  [far, scouts, reports, small, impi, farther, n...
#
#                                 Filtered Comment with tag  \
# 0       [(make, VB), (quick, JJ), (roxanne, NN), (korr...
# 1       [(well, RB), (thought, RB), (would, MD), (star...
# 2       [(hacking, VBG), (gagging, VBG), (spitting, VB...
# 3                 [(asking, VBG), (cute, NN), (name, NN)]
# 4         [(fault, NN), (proper, JJ), (introduction, NN)]
# ...                                                   ...
# 221611          [(orders, NNS), (mr, VBP), (vereker, NN)]
# 221612  [(take, VB), (sikali, NN), (main, JJ), (column...
# 221613  [(lord, NN), (chelmsford, NN), (seems, VBZ), (...
# 221614  [(well, RB), (assure, NN), (sir, NN), (desire,...
# 221615  [(assure, NN), (fact, NN), (would, MD), (oblig...
#
#                                   Filtered Reply with tag  \
# 0       [(well, RB), (thought, RB), (would, MD), (star...
# 1       [(hacking, VBG), (gagging, VBG), (spitting, VB...
# 2       [(okay, JJ), (try, NN), (french, JJ), (cuisine...
# 3                                          [(forget, NN)]
# 4                                         [(cameron, NN)]
# ...                                                   ...
# 221611  [(take, VB), (sikali, NN), (main, JJ), (column...
# 221612  [(lord, NN), (chelmsford, NN), (seems, VBZ), (...
# 221613  [(think, NN), (chelmsford, NN), (wants, VBZ), ...
# 221614  [(assure, NN), (fact, NN), (would, MD), (oblig...
# 221615  [(far, RB), (scouts, NNS), (reports, NNS), (sm...
#
#                             Filtered Comment with WordNet  \
# 0       [(make, v), (quick, a), (roxanne, n), (korrine...
# 1       [(well, r), (thought, r), (would, n), (start, ...
# 2       [(hacking, v), (gagging, v), (spitting, v), (p...
# 3                     [(asking, v), (cute, n), (name, n)]
# 4            [(fault, n), (proper, a), (introduction, n)]
# ...                                                   ...
# 221611               [(orders, n), (mr, v), (vereker, n)]
# 221612  [(take, v), (sikali, n), (main, a), (column, n...
# 221613  [(lord, n), (chelmsford, n), (seems, v), (want...
# 221614  [(well, r), (assure, n), (sir, n), (desire, n)...
# 221615  [(assure, n), (fact, n), (would, n), (obliged,...
#
#                               Filtered Reply with WordNet  \
# 0       [(well, r), (thought, r), (would, n), (start, ...
# 1       [(hacking, v), (gagging, v), (spitting, v), (p...
# 2       [(okay, a), (try, n), (french, a), (cuisine, n...
# 3                                           [(forget, n)]
# 4                                          [(cameron, n)]
# ...                                                   ...
# 221611  [(take, v), (sikali, n), (main, a), (column, n...
# 221612  [(lord, n), (chelmsford, n), (seems, v), (want...
# 221613  [(think, n), (chelmsford, n), (wants, v), (goo...
# 221614  [(assure, n), (fact, n), (would, n), (obliged,...
# 221615  [(far, r), (scouts, n), (reports, n), (small, ...
#
#                                        Lemmatized Comment  \
# 0       [make, quick, roxanne, korrine, andrew, barret...
# 1       [well, thought, would, start, pronunciation, o...
# 2                         [hack, gag, spit, part, please]
# 3                                       [ask, cute, name]
# 4                           [fault, proper, introduction]
# ...                                                   ...
# 221611                               [order, mr, vereker]
# 221612                [take, sikali, main, column, river]
# 221613  [lord, chelmsford, seem, want, stay, back, bas...
# 221614  [well, assure, sir, desire, create, difficulty...
# 221615  [assure, fact, would, oblige, best, advice, sc...
#
#                                          Lemmatized Reply  \
# 0       [well, thought, would, start, pronunciation, o...
# 1                         [hack, gag, spit, part, please]
# 2           [okay, try, french, cuisine, saturday, night]
# 3                                                [forget]
# 4                                               [cameron]
# ...                                                   ...
# 221611                [take, sikali, main, column, river]
# 221612  [lord, chelmsford, seem, want, stay, back, bas...
# 221613  [think, chelmsford, want, good, man, border, f...
# 221614  [assure, fact, would, oblige, best, advice, sc...
# 221615      [far, scout, report, small, impi, far, north]
#
#         Processed Comment Length  Processed Reply Length
# 0                             11                       6
# 1                              6                       5
# 2                              5                       6
# 3                              3                       1
# 4                              3                       1
# ...                          ...                     ...
# 221611                         3                       5
# 221612                         5                       7
# 221613                         7                      13
# 221614                         7                       8
# 221615                         8                       7
#
# [199749 rows x 16 columns]

# %%
all_words_comments_lemmatized3 = list(itertools.chain.from_iterable(df['Lemmatized Comment'][:]))
all_words_replies_lemmatized3 = list(itertools.chain.from_iterable(df['Lemmatized Reply'][:]))

# %%
fdist_common_comment_words_lemmatized3 = FreqDist(all_words_comments_lemmatized3)
fdist_common_comment_words_lemmatized3.most_common(20)
# Out:
# [('get', 19593),
#  ('go', 17728),
#  ('know', 16234),
#  ('like', 10656),
#  ('want', 10118),
#  ('would', 10063),
#  ('think', 9636),
#  ('say', 8789),
#  ('well', 7441),
#  ('one', 7142),
#  ('come', 6944),
#  ('tell', 6731),
#  ('see', 6636),
#  ('right', 6337),
#  ('look', 5695),
#  ('make', 5508),
#  ('take', 5465),
#  ('us', 5275),
#  ('good', 5160),
#  ('oh', 5039)]

# %%
fdist_common_reply_words_lemmatized3 = FreqDist(all_words_replies_lemmatized3)
fdist_common_reply_words_lemmatized3.most_common(20)
# Out:
# [('get', 20224),
#  ('go', 17448),
#  ('know', 17252),
#  ('like', 10770),
#  ('would', 10343),
#  ('want', 10317),
#  ('think', 9759),
#  ('say', 8782),
#  ('well', 8460),
#  ('one', 7527),
#  ('right', 7248),
#  ('come', 7052),
#  ('see', 6921),
#  ('tell', 6750),
#  ('yes', 6085),
#  ('yeah', 5810),
#  ('make', 5767),
#  ('look', 5722),
#  ('take', 5719),
#  ('oh', 5694)]

# %%
# Plotting the top 20 words for both comments and replies after lemmatizing and removing empty responses
fig6, ax6 = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
x_comment_word_lemmatized2 = dict(fdist_common_comment_words_lemmatized2.most_common(20)).keys()
y_comment_word_count_lemmatized2 = dict(fdist_common_comment_words_lemmatized2.most_common(20)).values()
x_reply_word_lemmatized2 = dict(fdist_common_reply_words_lemmatized2.most_common(20)).keys()
y_reply_word_count_lemmatized2 = dict(fdist_common_reply_words_lemmatized2.most_common(20)).values()
ax6[0].bar(x_comment_word_lemmatized2, y_comment_word_count_lemmatized2)
ax6[0].tick_params('x', rotation = 90)
ax6[0].set_title('Comments')
ax6[1].bar(x_reply_word_lemmatized2, y_reply_word_count_lemmatized2)
ax6[1].tick_params('x', rotation = 90)
ax6[1].set_title('Replies')
ax6[0].set_ylabel('Count')
fig6.suptitle('Word Count Lemmatized')
plt.show()

# %% [markdown]
# There might still be issues within the dataset, but we could start analyzing the data using NLTK's sentiment analyzer. As a start, the sentiment scores could be used to help categorize 'postive' from 'negative' responses. These could be features when start use the data for training our chatbot.

# %%
# Sentiment Analysis
sid = SentimentIntensityAnalyzer()
df['Sentiment Comment'] = df['Lemmatized Comment'].apply(lambda x: sid.polarity_scores(' '.join(x)))
df['Sentiment Reply'] = df['Lemmatized Reply'].apply(lambda x: sid.polarity_scores(' '.join(x)))
df
# Out:
#                                                   Comment  \
# 0       can we make this quick roxanne korrine and and...
# 1       well i thought we would start with pronunciati...
# 2       not the hacking and gagging and spitting part ...
# 3       you are asking me out that is so cute what is ...
# 4       no no it is my fault we did not have a proper ...
# ...                                                   ...
# 221611                             your orders mr vereker
# 221612  i am to take the sikali with the main column t...
# 221613  lord chelmsford seems to want me to stay back ...
# 221614  well i assure you sir i have no desire to crea...
# 221615  and i assure you you do not in fact i would be...
#
#                                                     Reply  Comment Length  \
# 0       well i thought we would start with pronunciati...              21
# 1       not the hacking and gagging and spitting part ...              14
# 2       okay then how about we try out some french cui...               9
# 3                                               forget it              14
# 4                                                 cameron              16
# ...                                                   ...             ...
# 221611  i am to take the sikali with the main column t...               4
# 221612  lord chelmsford seems to want me to stay back ...              13
# 221613  i think chelmsford wants a good man on the bor...              12
# 221614  and i assure you you do not in fact i would be...              13
# 221615  so far only their scouts but we have had repor...              22
#
#         Reply Length                                  Tokenized Comment  \
# 0                 14  [can, we, make, this, quick, roxanne, korrine,...
# 1                  9  [well, i, thought, we, would, start, with, pro...
# 2                 12  [not, the, hacking, and, gagging, and, spittin...
# 3                  2  [you, are, asking, me, out, that, is, so, cute...
# 4                  1  [no, no, it, is, my, fault, we, did, not, have...
# ...              ...                                                ...
# 221611            13                        [your, orders, mr, vereker]
# 221612            12  [i, am, to, take, the, sikali, with, the, main...
# 221613            23  [lord, chelmsford, seems, to, want, me, to, st...
# 221614            22  [well, i, assure, you, sir, i, have, no, desir...
# 221615            18  [and, i, assure, you, you, do, not, in, fact, ...
#
#                                           Tokenized Reply  \
# 0       [well, i, thought, we, would, start, with, pro...
# 1       [not, the, hacking, and, gagging, and, spittin...
# 2       [okay, then, how, about, we, try, out, some, f...
# 3                                            [forget, it]
# 4                                               [cameron]
# ...                                                   ...
# 221611  [i, am, to, take, the, sikali, with, the, main...
# 221612  [lord, chelmsford, seems, to, want, me, to, st...
# 221613  [i, think, chelmsford, wants, a, good, man, on...
# 221614  [and, i, assure, you, you, do, not, in, fact, ...
# 221615  [so, far, only, their, scouts, but, we, have, ...
#
#                                          Filtered Comment  \
# 0       [make, quick, roxanne, korrine, andrew, barret...
# 1       [well, thought, would, start, pronunciation, o...
# 2              [hacking, gagging, spitting, part, please]
# 3                                    [asking, cute, name]
# 4                           [fault, proper, introduction]
# ...                                                   ...
# 221611                              [orders, mr, vereker]
# 221612                [take, sikali, main, column, river]
# 221613  [lord, chelmsford, seems, want, stay, back, ba...
# 221614  [well, assure, sir, desire, create, difficulti...
# 221615  [assure, fact, would, obliged, best, advice, s...
#
#                                            Filtered Reply  \
# 0       [well, thought, would, start, pronunciation, o...
# 1              [hacking, gagging, spitting, part, please]
# 2           [okay, try, french, cuisine, saturday, night]
# 3                                                [forget]
# 4                                               [cameron]
# ...                                                   ...
# 221611                [take, sikali, main, column, river]
# 221612  [lord, chelmsford, seems, want, stay, back, ba...
# 221613  [think, chelmsford, wants, good, man, border, ...
# 221614  [assure, fact, would, obliged, best, advice, s...
# 221615  [far, scouts, reports, small, impi, farther, n...
#
#                                 Filtered Comment with tag  \
# 0       [(make, VB), (quick, JJ), (roxanne, NN), (korr...
# 1       [(well, RB), (thought, RB), (would, MD), (star...
# 2       [(hacking, VBG), (gagging, VBG), (spitting, VB...
# 3                 [(asking, VBG), (cute, NN), (name, NN)]
# 4         [(fault, NN), (proper, JJ), (introduction, NN)]
# ...                                                   ...
# 221611          [(orders, NNS), (mr, VBP), (vereker, NN)]
# 221612  [(take, VB), (sikali, NN), (main, JJ), (column...
# 221613  [(lord, NN), (chelmsford, NN), (seems, VBZ), (...
# 221614  [(well, RB), (assure, NN), (sir, NN), (desire,...
# 221615  [(assure, NN), (fact, NN), (would, MD), (oblig...
#
#                                   Filtered Reply with tag  \
# 0       [(well, RB), (thought, RB), (would, MD), (star...
# 1       [(hacking, VBG), (gagging, VBG), (spitting, VB...
# 2       [(okay, JJ), (try, NN), (french, JJ), (cuisine...
# 3                                          [(forget, NN)]
# 4                                         [(cameron, NN)]
# ...                                                   ...
# 221611  [(take, VB), (sikali, NN), (main, JJ), (column...
# 221612  [(lord, NN), (chelmsford, NN), (seems, VBZ), (...
# 221613  [(think, NN), (chelmsford, NN), (wants, VBZ), ...
# 221614  [(assure, NN), (fact, NN), (would, MD), (oblig...
# 221615  [(far, RB), (scouts, NNS), (reports, NNS), (sm...
#
#                             Filtered Comment with WordNet  \
# 0       [(make, v), (quick, a), (roxanne, n), (korrine...
# 1       [(well, r), (thought, r), (would, n), (start, ...
# 2       [(hacking, v), (gagging, v), (spitting, v), (p...
# 3                     [(asking, v), (cute, n), (name, n)]
# 4            [(fault, n), (proper, a), (introduction, n)]
# ...                                                   ...
# 221611               [(orders, n), (mr, v), (vereker, n)]
# 221612  [(take, v), (sikali, n), (main, a), (column, n...
# 221613  [(lord, n), (chelmsford, n), (seems, v), (want...
# 221614  [(well, r), (assure, n), (sir, n), (desire, n)...
# 221615  [(assure, n), (fact, n), (would, n), (obliged,...
#
#                               Filtered Reply with WordNet  \
# 0       [(well, r), (thought, r), (would, n), (start, ...
# 1       [(hacking, v), (gagging, v), (spitting, v), (p...
# 2       [(okay, a), (try, n), (french, a), (cuisine, n...
# 3                                           [(forget, n)]
# 4                                          [(cameron, n)]
# ...                                                   ...
# 221611  [(take, v), (sikali, n), (main, a), (column, n...
# 221612  [(lord, n), (chelmsford, n), (seems, v), (want...
# 221613  [(think, n), (chelmsford, n), (wants, v), (goo...
# 221614  [(assure, n), (fact, n), (would, n), (obliged,...
# 221615  [(far, r), (scouts, n), (reports, n), (small, ...
#
#                                        Lemmatized Comment  \
# 0       [make, quick, roxanne, korrine, andrew, barret...
# 1       [well, thought, would, start, pronunciation, o...
# 2                         [hack, gag, spit, part, please]
# 3                                       [ask, cute, name]
# 4                           [fault, proper, introduction]
# ...                                                   ...
# 221611                               [order, mr, vereker]
# 221612                [take, sikali, main, column, river]
# 221613  [lord, chelmsford, seem, want, stay, back, bas...
# 221614  [well, assure, sir, desire, create, difficulty...
# 221615  [assure, fact, would, oblige, best, advice, sc...
#
#                                          Lemmatized Reply  \
# 0       [well, thought, would, start, pronunciation, o...
# 1                         [hack, gag, spit, part, please]
# 2           [okay, try, french, cuisine, saturday, night]
# 3                                                [forget]
# 4                                               [cameron]
# ...                                                   ...
# 221611                [take, sikali, main, column, river]
# 221612  [lord, chelmsford, seem, want, stay, back, bas...
# 221613  [think, chelmsford, want, good, man, border, f...
# 221614  [assure, fact, would, oblige, best, advice, sc...
# 221615      [far, scout, report, small, impi, far, north]
#
#         Processed Comment Length  Processed Reply Length  \
# 0                             11                       6
# 1                              6                       5
# 2                              5                       6
# 3                              3                       1
# 4                              3                       1
# ...                          ...                     ...
# 221611                         3                       5
# 221612                         5                       7
# 221613                         7                      13
# 221614                         7                       8
# 221615                         8                       7
#
#                                         Sentiment Comment  \
# 0       {'neg': 0.29, 'neu': 0.71, 'pos': 0.0, 'compou...
# 1       {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound...
# 2       {'neg': 0.312, 'neu': 0.39, 'pos': 0.299, 'com...
# 3       {'neg': 0.0, 'neu': 0.4, 'pos': 0.6, 'compound...
# 4       {'neg': 0.574, 'neu': 0.426, 'pos': 0.0, 'comp...
# ...                                                   ...
# 221611  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 221612  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 221613  {'neg': 0.0, 'neu': 0.822, 'pos': 0.178, 'comp...
# 221614  {'neg': 0.175, 'neu': 0.146, 'pos': 0.679, 'co...
# 221615  {'neg': 0.0, 'neu': 0.476, 'pos': 0.524, 'comp...
#
#                                           Sentiment Reply
# 0       {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound...
# 1       {'neg': 0.312, 'neu': 0.39, 'pos': 0.299, 'com...
# 2       {'neg': 0.0, 'neu': 0.725, 'pos': 0.275, 'comp...
# 3       {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound...
# 4       {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# ...                                                   ...
# 221611  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 221612  {'neg': 0.0, 'neu': 0.822, 'pos': 0.178, 'comp...
# 221613  {'neg': 0.323, 'neu': 0.462, 'pos': 0.215, 'co...
# 221614  {'neg': 0.0, 'neu': 0.476, 'pos': 0.524, 'comp...
# 221615  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
#
# [199749 rows x 18 columns]

# %%
# Sentiment Analysis Compound Score
df['Sentiment Comment Compound Score'] = df['Sentiment Comment'].apply(lambda x: x['compound'])
df['Sentiment Reply Compound Score'] = df['Sentiment Reply'].apply(lambda x: x['compound'])
df
# Out:
#                                                   Comment  \
# 0       can we make this quick roxanne korrine and and...
# 1       well i thought we would start with pronunciati...
# 2       not the hacking and gagging and spitting part ...
# 3       you are asking me out that is so cute what is ...
# 4       no no it is my fault we did not have a proper ...
# ...                                                   ...
# 221611                             your orders mr vereker
# 221612  i am to take the sikali with the main column t...
# 221613  lord chelmsford seems to want me to stay back ...
# 221614  well i assure you sir i have no desire to crea...
# 221615  and i assure you you do not in fact i would be...
#
#                                                     Reply  Comment Length  \
# 0       well i thought we would start with pronunciati...              21
# 1       not the hacking and gagging and spitting part ...              14
# 2       okay then how about we try out some french cui...               9
# 3                                               forget it              14
# 4                                                 cameron              16
# ...                                                   ...             ...
# 221611  i am to take the sikali with the main column t...               4
# 221612  lord chelmsford seems to want me to stay back ...              13
# 221613  i think chelmsford wants a good man on the bor...              12
# 221614  and i assure you you do not in fact i would be...              13
# 221615  so far only their scouts but we have had repor...              22
#
#         Reply Length                                  Tokenized Comment  \
# 0                 14  [can, we, make, this, quick, roxanne, korrine,...
# 1                  9  [well, i, thought, we, would, start, with, pro...
# 2                 12  [not, the, hacking, and, gagging, and, spittin...
# 3                  2  [you, are, asking, me, out, that, is, so, cute...
# 4                  1  [no, no, it, is, my, fault, we, did, not, have...
# ...              ...                                                ...
# 221611            13                        [your, orders, mr, vereker]
# 221612            12  [i, am, to, take, the, sikali, with, the, main...
# 221613            23  [lord, chelmsford, seems, to, want, me, to, st...
# 221614            22  [well, i, assure, you, sir, i, have, no, desir...
# 221615            18  [and, i, assure, you, you, do, not, in, fact, ...
#
#                                           Tokenized Reply  \
# 0       [well, i, thought, we, would, start, with, pro...
# 1       [not, the, hacking, and, gagging, and, spittin...
# 2       [okay, then, how, about, we, try, out, some, f...
# 3                                            [forget, it]
# 4                                               [cameron]
# ...                                                   ...
# 221611  [i, am, to, take, the, sikali, with, the, main...
# 221612  [lord, chelmsford, seems, to, want, me, to, st...
# 221613  [i, think, chelmsford, wants, a, good, man, on...
# 221614  [and, i, assure, you, you, do, not, in, fact, ...
# 221615  [so, far, only, their, scouts, but, we, have, ...
#
#                                          Filtered Comment  \
# 0       [make, quick, roxanne, korrine, andrew, barret...
# 1       [well, thought, would, start, pronunciation, o...
# 2              [hacking, gagging, spitting, part, please]
# 3                                    [asking, cute, name]
# 4                           [fault, proper, introduction]
# ...                                                   ...
# 221611                              [orders, mr, vereker]
# 221612                [take, sikali, main, column, river]
# 221613  [lord, chelmsford, seems, want, stay, back, ba...
# 221614  [well, assure, sir, desire, create, difficulti...
# 221615  [assure, fact, would, obliged, best, advice, s...
#
#                                            Filtered Reply  \
# 0       [well, thought, would, start, pronunciation, o...
# 1              [hacking, gagging, spitting, part, please]
# 2           [okay, try, french, cuisine, saturday, night]
# 3                                                [forget]
# 4                                               [cameron]
# ...                                                   ...
# 221611                [take, sikali, main, column, river]
# 221612  [lord, chelmsford, seems, want, stay, back, ba...
# 221613  [think, chelmsford, wants, good, man, border, ...
# 221614  [assure, fact, would, obliged, best, advice, s...
# 221615  [far, scouts, reports, small, impi, farther, n...
#
#                                 Filtered Comment with tag  \
# 0       [(make, VB), (quick, JJ), (roxanne, NN), (korr...
# 1       [(well, RB), (thought, RB), (would, MD), (star...
# 2       [(hacking, VBG), (gagging, VBG), (spitting, VB...
# 3                 [(asking, VBG), (cute, NN), (name, NN)]
# 4         [(fault, NN), (proper, JJ), (introduction, NN)]
# ...                                                   ...
# 221611          [(orders, NNS), (mr, VBP), (vereker, NN)]
# 221612  [(take, VB), (sikali, NN), (main, JJ), (column...
# 221613  [(lord, NN), (chelmsford, NN), (seems, VBZ), (...
# 221614  [(well, RB), (assure, NN), (sir, NN), (desire,...
# 221615  [(assure, NN), (fact, NN), (would, MD), (oblig...
#
#                                   Filtered Reply with tag  \
# 0       [(well, RB), (thought, RB), (would, MD), (star...
# 1       [(hacking, VBG), (gagging, VBG), (spitting, VB...
# 2       [(okay, JJ), (try, NN), (french, JJ), (cuisine...
# 3                                          [(forget, NN)]
# 4                                         [(cameron, NN)]
# ...                                                   ...
# 221611  [(take, VB), (sikali, NN), (main, JJ), (column...
# 221612  [(lord, NN), (chelmsford, NN), (seems, VBZ), (...
# 221613  [(think, NN), (chelmsford, NN), (wants, VBZ), ...
# 221614  [(assure, NN), (fact, NN), (would, MD), (oblig...
# 221615  [(far, RB), (scouts, NNS), (reports, NNS), (sm...
#
#                             Filtered Comment with WordNet  \
# 0       [(make, v), (quick, a), (roxanne, n), (korrine...
# 1       [(well, r), (thought, r), (would, n), (start, ...
# 2       [(hacking, v), (gagging, v), (spitting, v), (p...
# 3                     [(asking, v), (cute, n), (name, n)]
# 4            [(fault, n), (proper, a), (introduction, n)]
# ...                                                   ...
# 221611               [(orders, n), (mr, v), (vereker, n)]
# 221612  [(take, v), (sikali, n), (main, a), (column, n...
# 221613  [(lord, n), (chelmsford, n), (seems, v), (want...
# 221614  [(well, r), (assure, n), (sir, n), (desire, n)...
# 221615  [(assure, n), (fact, n), (would, n), (obliged,...
#
#                               Filtered Reply with WordNet  \
# 0       [(well, r), (thought, r), (would, n), (start, ...
# 1       [(hacking, v), (gagging, v), (spitting, v), (p...
# 2       [(okay, a), (try, n), (french, a), (cuisine, n...
# 3                                           [(forget, n)]
# 4                                          [(cameron, n)]
# ...                                                   ...
# 221611  [(take, v), (sikali, n), (main, a), (column, n...
# 221612  [(lord, n), (chelmsford, n), (seems, v), (want...
# 221613  [(think, n), (chelmsford, n), (wants, v), (goo...
# 221614  [(assure, n), (fact, n), (would, n), (obliged,...
# 221615  [(far, r), (scouts, n), (reports, n), (small, ...
#
#                                        Lemmatized Comment  \
# 0       [make, quick, roxanne, korrine, andrew, barret...
# 1       [well, thought, would, start, pronunciation, o...
# 2                         [hack, gag, spit, part, please]
# 3                                       [ask, cute, name]
# 4                           [fault, proper, introduction]
# ...                                                   ...
# 221611                               [order, mr, vereker]
# 221612                [take, sikali, main, column, river]
# 221613  [lord, chelmsford, seem, want, stay, back, bas...
# 221614  [well, assure, sir, desire, create, difficulty...
# 221615  [assure, fact, would, oblige, best, advice, sc...
#
#                                          Lemmatized Reply  \
# 0       [well, thought, would, start, pronunciation, o...
# 1                         [hack, gag, spit, part, please]
# 2           [okay, try, french, cuisine, saturday, night]
# 3                                                [forget]
# 4                                               [cameron]
# ...                                                   ...
# 221611                [take, sikali, main, column, river]
# 221612  [lord, chelmsford, seem, want, stay, back, bas...
# 221613  [think, chelmsford, want, good, man, border, f...
# 221614  [assure, fact, would, oblige, best, advice, sc...
# 221615      [far, scout, report, small, impi, far, north]
#
#         Processed Comment Length  Processed Reply Length  \
# 0                             11                       6
# 1                              6                       5
# 2                              5                       6
# 3                              3                       1
# 4                              3                       1
# ...                          ...                     ...
# 221611                         3                       5
# 221612                         5                       7
# 221613                         7                      13
# 221614                         7                       8
# 221615                         8                       7
#
#                                         Sentiment Comment  \
# 0       {'neg': 0.29, 'neu': 0.71, 'pos': 0.0, 'compou...
# 1       {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound...
# 2       {'neg': 0.312, 'neu': 0.39, 'pos': 0.299, 'com...
# 3       {'neg': 0.0, 'neu': 0.4, 'pos': 0.6, 'compound...
# 4       {'neg': 0.574, 'neu': 0.426, 'pos': 0.0, 'comp...
# ...                                                   ...
# 221611  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 221612  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 221613  {'neg': 0.0, 'neu': 0.822, 'pos': 0.178, 'comp...
# 221614  {'neg': 0.175, 'neu': 0.146, 'pos': 0.679, 'co...
# 221615  {'neg': 0.0, 'neu': 0.476, 'pos': 0.524, 'comp...
#
#                                           Sentiment Reply  \
# 0       {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound...
# 1       {'neg': 0.312, 'neu': 0.39, 'pos': 0.299, 'com...
# 2       {'neg': 0.0, 'neu': 0.725, 'pos': 0.275, 'comp...
# 3       {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound...
# 4       {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# ...                                                   ...
# 221611  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 221612  {'neg': 0.0, 'neu': 0.822, 'pos': 0.178, 'comp...
# 221613  {'neg': 0.323, 'neu': 0.462, 'pos': 0.215, 'co...
# 221614  {'neg': 0.0, 'neu': 0.476, 'pos': 0.524, 'comp...
# 221615  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
#
#         Sentiment Comment Compound Score  Sentiment Reply Compound Score
# 0                                -0.6240                          0.4588
# 1                                 0.4588                         -0.0258
# 2                                -0.0258                          0.2263
# 3                                 0.4588                         -0.2263
# 4                                -0.4019                          0.0000
# ...                                  ...                             ...
# 221611                            0.0000                          0.0000
# 221612                            0.0000                          0.0772
# 221613                            0.0772                         -0.4767
# 221614                            0.7096                          0.7650
# 221615                            0.7650                          0.0000
#
# [199749 rows x 20 columns]

# %%
# Categorize Sentiment Analysis Compound Score
df['Sentiment Comment Classification'] = df['Sentiment Comment Compound Score'].apply(lambda x: 'positive' if x>0 else ('negative' if x<0 else 'neutral'))
df['Sentiment Reply Classification'] = df['Sentiment Reply Compound Score'].apply(lambda x: 'positive' if x>0 else ('negative' if x<0 else 'neutral'))
df
# Out:
#                                                   Comment  \
# 0       can we make this quick roxanne korrine and and...
# 1       well i thought we would start with pronunciati...
# 2       not the hacking and gagging and spitting part ...
# 3       you are asking me out that is so cute what is ...
# 4       no no it is my fault we did not have a proper ...
# ...                                                   ...
# 221611                             your orders mr vereker
# 221612  i am to take the sikali with the main column t...
# 221613  lord chelmsford seems to want me to stay back ...
# 221614  well i assure you sir i have no desire to crea...
# 221615  and i assure you you do not in fact i would be...
#
#                                                     Reply  Comment Length  \
# 0       well i thought we would start with pronunciati...              21
# 1       not the hacking and gagging and spitting part ...              14
# 2       okay then how about we try out some french cui...               9
# 3                                               forget it              14
# 4                                                 cameron              16
# ...                                                   ...             ...
# 221611  i am to take the sikali with the main column t...               4
# 221612  lord chelmsford seems to want me to stay back ...              13
# 221613  i think chelmsford wants a good man on the bor...              12
# 221614  and i assure you you do not in fact i would be...              13
# 221615  so far only their scouts but we have had repor...              22
#
#         Reply Length                                  Tokenized Comment  \
# 0                 14  [can, we, make, this, quick, roxanne, korrine,...
# 1                  9  [well, i, thought, we, would, start, with, pro...
# 2                 12  [not, the, hacking, and, gagging, and, spittin...
# 3                  2  [you, are, asking, me, out, that, is, so, cute...
# 4                  1  [no, no, it, is, my, fault, we, did, not, have...
# ...              ...                                                ...
# 221611            13                        [your, orders, mr, vereker]
# 221612            12  [i, am, to, take, the, sikali, with, the, main...
# 221613            23  [lord, chelmsford, seems, to, want, me, to, st...
# 221614            22  [well, i, assure, you, sir, i, have, no, desir...
# 221615            18  [and, i, assure, you, you, do, not, in, fact, ...
#
#                                           Tokenized Reply  \
# 0       [well, i, thought, we, would, start, with, pro...
# 1       [not, the, hacking, and, gagging, and, spittin...
# 2       [okay, then, how, about, we, try, out, some, f...
# 3                                            [forget, it]
# 4                                               [cameron]
# ...                                                   ...
# 221611  [i, am, to, take, the, sikali, with, the, main...
# 221612  [lord, chelmsford, seems, to, want, me, to, st...
# 221613  [i, think, chelmsford, wants, a, good, man, on...
# 221614  [and, i, assure, you, you, do, not, in, fact, ...
# 221615  [so, far, only, their, scouts, but, we, have, ...
#
#                                          Filtered Comment  \
# 0       [make, quick, roxanne, korrine, andrew, barret...
# 1       [well, thought, would, start, pronunciation, o...
# 2              [hacking, gagging, spitting, part, please]
# 3                                    [asking, cute, name]
# 4                           [fault, proper, introduction]
# ...                                                   ...
# 221611                              [orders, mr, vereker]
# 221612                [take, sikali, main, column, river]
# 221613  [lord, chelmsford, seems, want, stay, back, ba...
# 221614  [well, assure, sir, desire, create, difficulti...
# 221615  [assure, fact, would, obliged, best, advice, s...
#
#                                            Filtered Reply  \
# 0       [well, thought, would, start, pronunciation, o...
# 1              [hacking, gagging, spitting, part, please]
# 2           [okay, try, french, cuisine, saturday, night]
# 3                                                [forget]
# 4                                               [cameron]
# ...                                                   ...
# 221611                [take, sikali, main, column, river]
# 221612  [lord, chelmsford, seems, want, stay, back, ba...
# 221613  [think, chelmsford, wants, good, man, border, ...
# 221614  [assure, fact, would, obliged, best, advice, s...
# 221615  [far, scouts, reports, small, impi, farther, n...
#
#                                 Filtered Comment with tag  \
# 0       [(make, VB), (quick, JJ), (roxanne, NN), (korr...
# 1       [(well, RB), (thought, RB), (would, MD), (star...
# 2       [(hacking, VBG), (gagging, VBG), (spitting, VB...
# 3                 [(asking, VBG), (cute, NN), (name, NN)]
# 4         [(fault, NN), (proper, JJ), (introduction, NN)]
# ...                                                   ...
# 221611          [(orders, NNS), (mr, VBP), (vereker, NN)]
# 221612  [(take, VB), (sikali, NN), (main, JJ), (column...
# 221613  [(lord, NN), (chelmsford, NN), (seems, VBZ), (...
# 221614  [(well, RB), (assure, NN), (sir, NN), (desire,...
# 221615  [(assure, NN), (fact, NN), (would, MD), (oblig...
#
#                                   Filtered Reply with tag  ...  \
# 0       [(well, RB), (thought, RB), (would, MD), (star...  ...
# 1       [(hacking, VBG), (gagging, VBG), (spitting, VB...  ...
# 2       [(okay, JJ), (try, NN), (french, JJ), (cuisine...  ...
# 3                                          [(forget, NN)]  ...
# 4                                         [(cameron, NN)]  ...
# ...                                                   ...  ...
# 221611  [(take, VB), (sikali, NN), (main, JJ), (column...  ...
# 221612  [(lord, NN), (chelmsford, NN), (seems, VBZ), (...  ...
# 221613  [(think, NN), (chelmsford, NN), (wants, VBZ), ...  ...
# 221614  [(assure, NN), (fact, NN), (would, MD), (oblig...  ...
# 221615  [(far, RB), (scouts, NNS), (reports, NNS), (sm...  ...
#
#                                        Lemmatized Comment  \
# 0       [make, quick, roxanne, korrine, andrew, barret...
# 1       [well, thought, would, start, pronunciation, o...
# 2                         [hack, gag, spit, part, please]
# 3                                       [ask, cute, name]
# 4                           [fault, proper, introduction]
# ...                                                   ...
# 221611                               [order, mr, vereker]
# 221612                [take, sikali, main, column, river]
# 221613  [lord, chelmsford, seem, want, stay, back, bas...
# 221614  [well, assure, sir, desire, create, difficulty...
# 221615  [assure, fact, would, oblige, best, advice, sc...
#
#                                          Lemmatized Reply  \
# 0       [well, thought, would, start, pronunciation, o...
# 1                         [hack, gag, spit, part, please]
# 2           [okay, try, french, cuisine, saturday, night]
# 3                                                [forget]
# 4                                               [cameron]
# ...                                                   ...
# 221611                [take, sikali, main, column, river]
# 221612  [lord, chelmsford, seem, want, stay, back, bas...
# 221613  [think, chelmsford, want, good, man, border, f...
# 221614  [assure, fact, would, oblige, best, advice, sc...
# 221615      [far, scout, report, small, impi, far, north]
#
#        Processed Comment Length Processed Reply Length  \
# 0                            11                      6
# 1                             6                      5
# 2                             5                      6
# 3                             3                      1
# 4                             3                      1
# ...                         ...                    ...
# 221611                        3                      5
# 221612                        5                      7
# 221613                        7                     13
# 221614                        7                      8
# 221615                        8                      7
#
#                                         Sentiment Comment  \
# 0       {'neg': 0.29, 'neu': 0.71, 'pos': 0.0, 'compou...
# 1       {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound...
# 2       {'neg': 0.312, 'neu': 0.39, 'pos': 0.299, 'com...
# 3       {'neg': 0.0, 'neu': 0.4, 'pos': 0.6, 'compound...
# 4       {'neg': 0.574, 'neu': 0.426, 'pos': 0.0, 'comp...
# ...                                                   ...
# 221611  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 221612  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 221613  {'neg': 0.0, 'neu': 0.822, 'pos': 0.178, 'comp...
# 221614  {'neg': 0.175, 'neu': 0.146, 'pos': 0.679, 'co...
# 221615  {'neg': 0.0, 'neu': 0.476, 'pos': 0.524, 'comp...
#
#                                           Sentiment Reply  \
# 0       {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound...
# 1       {'neg': 0.312, 'neu': 0.39, 'pos': 0.299, 'com...
# 2       {'neg': 0.0, 'neu': 0.725, 'pos': 0.275, 'comp...
# 3       {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound...
# 4       {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# ...                                                   ...
# 221611  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 221612  {'neg': 0.0, 'neu': 0.822, 'pos': 0.178, 'comp...
# 221613  {'neg': 0.323, 'neu': 0.462, 'pos': 0.215, 'co...
# 221614  {'neg': 0.0, 'neu': 0.476, 'pos': 0.524, 'comp...
# 221615  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
#
#        Sentiment Comment Compound Score Sentiment Reply Compound Score  \
# 0                               -0.6240                         0.4588
# 1                                0.4588                        -0.0258
# 2                               -0.0258                         0.2263
# 3                                0.4588                        -0.2263
# 4                               -0.4019                         0.0000
# ...                                 ...                            ...
# 221611                           0.0000                         0.0000
# 221612                           0.0000                         0.0772
# 221613                           0.0772                        -0.4767
# 221614                           0.7096                         0.7650
# 221615                           0.7650                         0.0000
#
#         Sentiment Comment Classification  Sentiment Reply Classification
# 0                               negative                        positive
# 1                               positive                        negative
# 2                               negative                        positive
# 3                               positive                        negative
# 4                               negative                         neutral
# ...                                  ...                             ...
# 221611                           neutral                         neutral
# 221612                           neutral                        positive
# 221613                          positive                        negative
# 221614                          positive                        positive
# 221615                          positive                         neutral
#
# [199749 rows x 22 columns]

# %%
df['Sentiment Comment Compound Score'].hist()
plt.title('Sentiment Comment Compound Score')
plt.xlabel('Score')
plt.ylabel('Count')
plt.show()

# %%
df['Sentiment Reply Compound Score'].hist()
plt.title('Sentiment Reply Compound Score')
plt.xlabel('Score')
plt.ylabel('Count')
plt.show()

# %%
# Sentiment Analysis Compound Score Overall
df['Sentiment Score Overall'] = df['Sentiment Comment Compound Score'] + df['Sentiment Reply Compound Score']
df['Sentiment Score Overall Classification'] = df['Sentiment Score Overall'].apply(lambda x: 'positive' if x>0 else ('negative' if x<0 else 'neutral'))
df
# Out:
#                                                   Comment  \
# 0       can we make this quick roxanne korrine and and...
# 1       well i thought we would start with pronunciati...
# 2       not the hacking and gagging and spitting part ...
# 3       you are asking me out that is so cute what is ...
# 4       no no it is my fault we did not have a proper ...
# ...                                                   ...
# 221611                             your orders mr vereker
# 221612  i am to take the sikali with the main column t...
# 221613  lord chelmsford seems to want me to stay back ...
# 221614  well i assure you sir i have no desire to crea...
# 221615  and i assure you you do not in fact i would be...
#
#                                                     Reply  Comment Length  \
# 0       well i thought we would start with pronunciati...              21
# 1       not the hacking and gagging and spitting part ...              14
# 2       okay then how about we try out some french cui...               9
# 3                                               forget it              14
# 4                                                 cameron              16
# ...                                                   ...             ...
# 221611  i am to take the sikali with the main column t...               4
# 221612  lord chelmsford seems to want me to stay back ...              13
# 221613  i think chelmsford wants a good man on the bor...              12
# 221614  and i assure you you do not in fact i would be...              13
# 221615  so far only their scouts but we have had repor...              22
#
#         Reply Length                                  Tokenized Comment  \
# 0                 14  [can, we, make, this, quick, roxanne, korrine,...
# 1                  9  [well, i, thought, we, would, start, with, pro...
# 2                 12  [not, the, hacking, and, gagging, and, spittin...
# 3                  2  [you, are, asking, me, out, that, is, so, cute...
# 4                  1  [no, no, it, is, my, fault, we, did, not, have...
# ...              ...                                                ...
# 221611            13                        [your, orders, mr, vereker]
# 221612            12  [i, am, to, take, the, sikali, with, the, main...
# 221613            23  [lord, chelmsford, seems, to, want, me, to, st...
# 221614            22  [well, i, assure, you, sir, i, have, no, desir...
# 221615            18  [and, i, assure, you, you, do, not, in, fact, ...
#
#                                           Tokenized Reply  \
# 0       [well, i, thought, we, would, start, with, pro...
# 1       [not, the, hacking, and, gagging, and, spittin...
# 2       [okay, then, how, about, we, try, out, some, f...
# 3                                            [forget, it]
# 4                                               [cameron]
# ...                                                   ...
# 221611  [i, am, to, take, the, sikali, with, the, main...
# 221612  [lord, chelmsford, seems, to, want, me, to, st...
# 221613  [i, think, chelmsford, wants, a, good, man, on...
# 221614  [and, i, assure, you, you, do, not, in, fact, ...
# 221615  [so, far, only, their, scouts, but, we, have, ...
#
#                                          Filtered Comment  \
# 0       [make, quick, roxanne, korrine, andrew, barret...
# 1       [well, thought, would, start, pronunciation, o...
# 2              [hacking, gagging, spitting, part, please]
# 3                                    [asking, cute, name]
# 4                           [fault, proper, introduction]
# ...                                                   ...
# 221611                              [orders, mr, vereker]
# 221612                [take, sikali, main, column, river]
# 221613  [lord, chelmsford, seems, want, stay, back, ba...
# 221614  [well, assure, sir, desire, create, difficulti...
# 221615  [assure, fact, would, obliged, best, advice, s...
#
#                                            Filtered Reply  \
# 0       [well, thought, would, start, pronunciation, o...
# 1              [hacking, gagging, spitting, part, please]
# 2           [okay, try, french, cuisine, saturday, night]
# 3                                                [forget]
# 4                                               [cameron]
# ...                                                   ...
# 221611                [take, sikali, main, column, river]
# 221612  [lord, chelmsford, seems, want, stay, back, ba...
# 221613  [think, chelmsford, wants, good, man, border, ...
# 221614  [assure, fact, would, obliged, best, advice, s...
# 221615  [far, scouts, reports, small, impi, farther, n...
#
#                                 Filtered Comment with tag  \
# 0       [(make, VB), (quick, JJ), (roxanne, NN), (korr...
# 1       [(well, RB), (thought, RB), (would, MD), (star...
# 2       [(hacking, VBG), (gagging, VBG), (spitting, VB...
# 3                 [(asking, VBG), (cute, NN), (name, NN)]
# 4         [(fault, NN), (proper, JJ), (introduction, NN)]
# ...                                                   ...
# 221611          [(orders, NNS), (mr, VBP), (vereker, NN)]
# 221612  [(take, VB), (sikali, NN), (main, JJ), (column...
# 221613  [(lord, NN), (chelmsford, NN), (seems, VBZ), (...
# 221614  [(well, RB), (assure, NN), (sir, NN), (desire,...
# 221615  [(assure, NN), (fact, NN), (would, MD), (oblig...
#
#                                   Filtered Reply with tag  ...  \
# 0       [(well, RB), (thought, RB), (would, MD), (star...  ...
# 1       [(hacking, VBG), (gagging, VBG), (spitting, VB...  ...
# 2       [(okay, JJ), (try, NN), (french, JJ), (cuisine...  ...
# 3                                          [(forget, NN)]  ...
# 4                                         [(cameron, NN)]  ...
# ...                                                   ...  ...
# 221611  [(take, VB), (sikali, NN), (main, JJ), (column...  ...
# 221612  [(lord, NN), (chelmsford, NN), (seems, VBZ), (...  ...
# 221613  [(think, NN), (chelmsford, NN), (wants, VBZ), ...  ...
# 221614  [(assure, NN), (fact, NN), (would, MD), (oblig...  ...
# 221615  [(far, RB), (scouts, NNS), (reports, NNS), (sm...  ...
#
#        Processed Comment Length Processed Reply Length  \
# 0                            11                      6
# 1                             6                      5
# 2                             5                      6
# 3                             3                      1
# 4                             3                      1
# ...                         ...                    ...
# 221611                        3                      5
# 221612                        5                      7
# 221613                        7                     13
# 221614                        7                      8
# 221615                        8                      7
#
#                                         Sentiment Comment  \
# 0       {'neg': 0.29, 'neu': 0.71, 'pos': 0.0, 'compou...
# 1       {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound...
# 2       {'neg': 0.312, 'neu': 0.39, 'pos': 0.299, 'com...
# 3       {'neg': 0.0, 'neu': 0.4, 'pos': 0.6, 'compound...
# 4       {'neg': 0.574, 'neu': 0.426, 'pos': 0.0, 'comp...
# ...                                                   ...
# 221611  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 221612  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 221613  {'neg': 0.0, 'neu': 0.822, 'pos': 0.178, 'comp...
# 221614  {'neg': 0.175, 'neu': 0.146, 'pos': 0.679, 'co...
# 221615  {'neg': 0.0, 'neu': 0.476, 'pos': 0.524, 'comp...
#
#                                           Sentiment Reply  \
# 0       {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound...
# 1       {'neg': 0.312, 'neu': 0.39, 'pos': 0.299, 'com...
# 2       {'neg': 0.0, 'neu': 0.725, 'pos': 0.275, 'comp...
# 3       {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound...
# 4       {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# ...                                                   ...
# 221611  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 221612  {'neg': 0.0, 'neu': 0.822, 'pos': 0.178, 'comp...
# 221613  {'neg': 0.323, 'neu': 0.462, 'pos': 0.215, 'co...
# 221614  {'neg': 0.0, 'neu': 0.476, 'pos': 0.524, 'comp...
# 221615  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
#
#         Sentiment Comment Compound Score  Sentiment Reply Compound Score  \
# 0                                -0.6240                          0.4588
# 1                                 0.4588                         -0.0258
# 2                                -0.0258                          0.2263
# 3                                 0.4588                         -0.2263
# 4                                -0.4019                          0.0000
# ...                                  ...                             ...
# 221611                            0.0000                          0.0000
# 221612                            0.0000                          0.0772
# 221613                            0.0772                         -0.4767
# 221614                            0.7096                          0.7650
# 221615                            0.7650                          0.0000
#
#        Sentiment Comment Classification Sentiment Reply Classification  \
# 0                              negative                       positive
# 1                              positive                       negative
# 2                              negative                       positive
# 3                              positive                       negative
# 4                              negative                        neutral
# ...                                 ...                            ...
# 221611                          neutral                        neutral
# 221612                          neutral                       positive
# 221613                         positive                       negative
# 221614                         positive                       positive
# 221615                         positive                        neutral
#
#         Sentiment Score Overall  Sentiment Score Overall Classification
# 0                       -0.1652                                negative
# 1                        0.4330                                positive
# 2                        0.2005                                positive
# 3                        0.2325                                positive
# 4                       -0.4019                                negative
# ...                         ...                                     ...
# 221611                   0.0000                                 neutral
# 221612                   0.0772                                positive
# 221613                  -0.3995                                negative
# 221614                   1.4746                                positive
# 221615                   0.7650                                positive
#
# [199749 rows x 24 columns]

# %%
df['Sentiment Score Overall'].hist()
plt.title('Sentiment Score Overall')
plt.xlabel('Score')
plt.ylabel('Count')
plt.show()

# %%
df['Sentiment Score Overall Classification'].hist()
plt.title('Sentiment Score')
plt.xlabel('Classification')
plt.ylabel('Count')
plt.show()
