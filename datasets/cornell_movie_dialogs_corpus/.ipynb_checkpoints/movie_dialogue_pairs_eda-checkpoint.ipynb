# %% [markdown]
# # Exploratory Data Analysis
#
# Having processed our movie data from Cornell, we'll proceed to explore our data. To do this, the following dependencies would be loaded. Pandas for organize our data, nltk for NLP, matplotlib and seaborn for plotting, and itertools and collections to assist in data structuring.

# %%
# Importing dependencies
import pandas as pd
import nltk
import itertools
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from nltk.probability import FreqDist
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
# Loading processed file from our data cleaning process
file = 'processed_movie_dialogues.csv'
df = pd.read_csv(file)

# %%
df
# Out:
#         Unnamed: 0                                            Comment  \
# 0                0  Can we make this quick? Roxanne Korrine and An...
# 1                1  Well, I thought we'd start with pronunciation,...
# 2                2  Not the hacking and gagging and spitting part ...
# 3                3  You're asking me out That's so cute What's you...
# 4                4  No, no, it's my fault - we didn't have a prope...
# ...            ...                                                ...
# 214681      221611                           Your orders, Mr Vereker?
# 214682      221612  I'm to take the Sikali with the main column to...
# 214683      221613  Lord Chelmsford seems to want me to stay back ...
# 214684      221614  Well I assure you, Sir, I have no desire to cr...
# 214685      221615  And I assure you, you do not In fact I'd be ob...
#
#                                                     Reply  \
# 0       Well, I thought we'd start with pronunciation,...
# ...

# %%
# Dropping extraneous column from the DataFrame
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df
# Out:
#                                                   Comment  \
# 0       Can we make this quick? Roxanne Korrine and An...
# 1       Well, I thought we'd start with pronunciation,...
# 2       Not the hacking and gagging and spitting part ...
# 3       You're asking me out That's so cute What's you...
# 4       No, no, it's my fault - we didn't have a prope...
# ...                                                   ...
# 214681                           Your orders, Mr Vereker?
# 214682  I'm to take the Sikali with the main column to...
# 214683  Lord Chelmsford seems to want me to stay back ...
# 214684  Well I assure you, Sir, I have no desire to cr...
# 214685  And I assure you, you do not In fact I'd be ob...
#
#                                                     Reply  \
# 0       Well, I thought we'd start with pronunciation,...
# 1       Not the hacking and gagging and spitting part ...
# 2       Okay then how 'bout we try out some French cui...
# ...

# %%
# Checking data types in DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214686 entries, 0 to 214685
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Comment           214685 non-null  object
#  1   Reply             214685 non-null  object
#  2   Expanded Comment  214680 non-null  object
#  3   Expanded Reply    214683 non-null  object
#  4   Comment Length    214686 non-null  int64
#  5   Reply Length      214686 non-null  int64
# dtypes: int64(2), object(4)
# memory usage: 9.8+ MB

# %% [markdown]
# From this information, we could see that there are null values in our DataFrame. Comments without replies or replies with out comments would be processed out.

# %%
df[df['Expanded Comment'].isna() == True]
# Out:
#        Comment                                              Reply  \
# 35305      NaN                                                NaN
# 35522    **?!!                        Newer, more powerful design
# 84818      ???                                              What?
# 84843      ???   I don't believe this I don't bloody believe this
# 84975      ???  ???  virginity, right Mother? Poverty, chastit...
# 147329      ?!                               It has a broken leg!
#
#        Expanded Comment                                     Expanded Reply  \
# 35305               NaN                                                NaN
# 35522               NaN                         newer more powerful design
# 84818               NaN                                               what
# 84843               NaN  i do not believe this i do not bloody believe ...
# 84975               NaN  virginity right mother poverty chastity and ig...
# ...

# %%
df[df['Expanded Reply'].isna() == True]
# Out:
#                             Comment  Reply           Expanded Comment  \
# 35305                           NaN    NaN                        NaN
# 35521                       PEM115!  **?!!                     pem115
# 84817  Agnes? Who? Mother Superior?    ???  agnes who mother superior
#
#       Expanded Reply  Comment Length  Reply Length
# 35305            NaN               0             0
# 35521            NaN               1             1
# 84817            NaN               4             1

# %% [markdown]
# There seems to be stray NaNs in our dataset as well as weird comments and replies that are just punctuations. In our case, we'll simply remove them all since they are not proper (comment, reply) responses regardless of what the original comment or reply was.

# %%
# Dropping NaNs from dataset
df = df.drop(df[df['Expanded Comment'].isna()].index)
df = df.drop(df[df['Expanded Reply'].isna()].index)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 214678 entries, 0 to 214685
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Comment           214678 non-null  object
#  1   Reply             214678 non-null  object
#  2   Expanded Comment  214678 non-null  object
#  3   Expanded Reply    214678 non-null  object
#  4   Comment Length    214678 non-null  int64
#  5   Reply Length      214678 non-null  int64
# dtypes: int64(2), object(4)
# memory usage: 11.5+ MB

# %% [markdown]
# Before utilizing the full capacity of NLTK for NLP, we'll first explore the frequency of repsonses.

# %%
# Checking the frequency of comments using NLTK's FreqDist() function
fdist_common_comments = FreqDist(df['Expanded Comment'])
fdist_common_comments.most_common(20)
# Out:
# [('what', 1701),
#  ('yes', 1359),
#  ('no', 1275),
#  ('yeah', 1015),
#  ('why', 522),
#  ('i do not know', 300),
#  ('hello', 257),
#  ('who', 248),
#  ('why not', 223),
#  ('what is it', 215),
#  ('what do you mean', 211),
#  ('oh', 210),
#  ('what is that', 207),
#  ('none', 204),
#  ('okay', 200),
#  ('what are you doing', 196),
#  ('really', 188),
#  ('huh', 188),
#  ('hi', 186),
#  ('uh huh', 186)]

# %%
# Checking the frequency of replies using NLTK's FreqDist() function
fdist_common_replies = FreqDist(df['Expanded Reply'])
fdist_common_replies.most_common(20)
# Out:
# [('what', 1595),
#  ('yes', 1521),
#  ('no', 1474),
#  ('yeah', 1150),
#  ('why', 513),
#  ('i do not know', 405),
#  ('okay', 370),
#  ('oh', 291),
#  ('sure', 280),
#  ('yes sir', 248),
#  ('who', 247),
#  ('thank you', 247),
#  ('why not', 242),
#  ('i know', 231),
#  ('uh huh', 226),
#  ('right', 211),
#  ('none', 210),
#  ('huh', 210),
#  ('what do you mean', 205),
#  ('really', 204)]

# %%
# Plotting the top 20 responses for both comments and replies
fig1, ax1 = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
x_comment = dict(fdist_common_comments.most_common(20)).keys()
y_comment_count = dict(fdist_common_comments.most_common(20)).values()
x_reply = dict(fdist_common_replies.most_common(20)).keys()
y_reply_count = dict(fdist_common_replies.most_common(20)).values()
ax1[0].bar(x_comment, y_comment_count)
ax1[0].tick_params('x', rotation = 90)
ax1[0].set_title('Comments')
ax1[1].bar(x_reply, y_reply_count)
ax1[1].tick_params('x', rotation = 90)
ax1[1].set_title('Replies')
ax1[0].set_ylabel('Count')
fig1.suptitle('Response Count')
plt.show()

# %% [markdown]
# In order for us to use the data later on for training and testing, the responses needs to be broken down into tokens. For this, we will utilize NLTK's word tokenizer, the word_tokenize() function.

# %%
# Tokenizing Text using NLTK's word tokenizer
df['Tokenized Comment'] = df['Expanded Comment'].apply(word_tokenize)
df['Tokenized Reply'] = df['Expanded Reply'].apply(word_tokenize)
df
# Out:
#                                                   Comment  \
# 0       Can we make this quick? Roxanne Korrine and An...
# 1       Well, I thought we'd start with pronunciation,...
# 2       Not the hacking and gagging and spitting part ...
# 3       You're asking me out That's so cute What's you...
# 4       No, no, it's my fault - we didn't have a prope...
# ...                                                   ...
# 214681                           Your orders, Mr Vereker?
# 214682  I'm to take the Sikali with the main column to...
# 214683  Lord Chelmsford seems to want me to stay back ...
# 214684  Well I assure you, Sir, I have no desire to cr...
# 214685  And I assure you, you do not In fact I'd be ob...
#
#                                                     Reply  \
# 0       Well, I thought we'd start with pronunciation,...
# 1       Not the hacking and gagging and spitting part ...
# 2       Okay then how 'bout we try out some French cui...
# ...

# %% [markdown]
# We could check the frequency of individual words after being tokenized.

# %%
# Taking the lists from DataFrame and flattening it into one list
all_words_comments = list(itertools.chain.from_iterable(df['Tokenized Comment'][:]))
all_words_replies = list(itertools.chain.from_iterable(df['Tokenized Reply'][:]))

# %%
fdist_common_comment_words = FreqDist(all_words_comments)
fdist_common_comment_words.most_common(20)
# Out:
# [('you', 100296),
#  ('i', 88262),
#  ('the', 60414),
#  ('to', 54754),
#  ('is', 53336),
#  ('not', 46632),
#  ('a', 43884),
#  ('it', 41142),
#  ('do', 30917),
#  ('that', 29341),
#  ('what', 27842),
#  ('are', 26321),
#  ('and', 25679),
#  ('of', 23866),
#  ('have', 22049),
#  ('in', 20841),
#  ('me', 20426),
#  ('we', 18346),
#  ('he', 16751),
#  ('am', 16248)]

# %%
fdist_common_reply_words = FreqDist(all_words_replies)
fdist_common_reply_words.most_common(20)
# Out:
# [('i', 95757),
#  ('you', 95366),
#  ('the', 60823),
#  ('to', 55505),
#  ('is', 53244),
#  ('not', 50307),
#  ('a', 45543),
#  ('it', 44202),
#  ('do', 31618),
#  ('that', 30265),
#  ('and', 27500),
#  ('of', 24662),
#  ('are', 24465),
#  ('what', 24008),
#  ('have', 22100),
#  ('in', 21440),
#  ('me', 21146),
#  ('we', 18419),
#  ('he', 17665),
#  ('am', 17604)]

# %%
# Plotting the top 20 words for both comments and replies
fig2, ax2 = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
x_comment_word = dict(fdist_common_comment_words.most_common(20)).keys()
y_comment_word_count = dict(fdist_common_comment_words.most_common(20)).values()
x_reply_word = dict(fdist_common_reply_words.most_common(20)).keys()
y_reply_word_count = dict(fdist_common_reply_words.most_common(20)).values()
ax2[0].bar(x_comment_word, y_comment_word_count)
ax2[0].tick_params('x', rotation = 90)
ax2[0].set_title('Comments')
ax2[1].bar(x_reply_word, y_reply_word_count)
ax2[1].tick_params('x', rotation = 90)
ax2[1].set_title('Replies')
ax2[0].set_ylabel('Count')
fig2.suptitle('Word Count')
plt.show()

# %% [markdown]
# Stop words are very useful when carrying out a conversation, but the words themselves carry very little information by themselves. Thus for NLP, stop-words are typically removed. However, dialogues without stop-words might appear robotic or clunky and context might be lost as a result. Therefore, we'll generate new columns without stop-words, but also keep the columns with stop-words.
#
# Columns with stop-words removed will be tagged using 'no_sw'. For the removal of stop-words, we'll also be utilizing the ones stored in NLTK's stopwords.words().

# %%
# Defining function to remove stop-words from our dataset
stop_words = set(stopwords.words("english"))
def remove_stopwords(text):
    return [i for i in text if i not in stop_words]

# %%
# Removing stop words
df['Tokenized Comment_no_sw'] = df['Tokenized Comment'].apply(remove_stopwords)
df['Tokenized Reply_no_sw'] = df['Tokenized Reply'].apply(remove_stopwords)
df
# Out:
#                                                   Comment  \
# 0       Can we make this quick? Roxanne Korrine and An...
# 1       Well, I thought we'd start with pronunciation,...
# 2       Not the hacking and gagging and spitting part ...
# 3       You're asking me out That's so cute What's you...
# 4       No, no, it's my fault - we didn't have a prope...
# ...                                                   ...
# 214681                           Your orders, Mr Vereker?
# 214682  I'm to take the Sikali with the main column to...
# 214683  Lord Chelmsford seems to want me to stay back ...
# 214684  Well I assure you, Sir, I have no desire to cr...
# 214685  And I assure you, you do not In fact I'd be ob...
#
#                                                     Reply  \
# 0       Well, I thought we'd start with pronunciation,...
# 1       Not the hacking and gagging and spitting part ...
# 2       Okay then how 'bout we try out some French cui...
# ...

# %%
all_words_comments_no_stop = list(itertools.chain.from_iterable(df['Tokenized Comment_no_sw'][:]))
all_words_replies_no_stop = list(itertools.chain.from_iterable(df['Tokenized Reply_no_sw'][:]))

# %%
fdist_common_comment_words_no_stop = FreqDist(all_words_comments_no_stop)
fdist_common_comment_words_no_stop.most_common(20)
# Out:
# [('know', 13981),
#  ('like', 9534),
#  ('would', 9383),
#  ('get', 8670),
#  ('going', 8585),
#  ('got', 8355),
#  ('want', 7945),
#  ('think', 7039),
#  ('one', 6558),
#  ('go', 6196),
#  ('well', 6164),
#  ('right', 5996),
#  ('oh', 5104),
#  ('see', 5024),
#  ('us', 4986),
#  ('yes', 4886),
#  ('could', 4613),
#  ('good', 4582),
#  ('tell', 4439),
#  ('yeah', 4438)]

# %%
fdist_common_reply_words_no_stop = FreqDist(all_words_replies_no_stop)
fdist_common_reply_words_no_stop.most_common(20)
# Out:
# [('know', 14954),
#  ('like', 9684),
#  ('would', 9566),
#  ('get', 9110),
#  ('got', 8475),
#  ('going', 8040),
#  ('want', 7929),
#  ('think', 7073),
#  ('well', 7046),
#  ('right', 6872),
#  ('one', 6859),
#  ('go', 6406),
#  ('yes', 6149),
#  ('yeah', 5792),
#  ('oh', 5705),
#  ('see', 5253),
#  ('us', 5247),
#  ('good', 5013),
#  ('could', 4598),
#  ('tell', 4408)]

# %%
# Plotting the top 20 words for both comments and replies after removing stop words
fig3, ax3 = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
x_comment_word_no_stop = dict(fdist_common_comment_words_no_stop.most_common(20)).keys()
y_comment_word_count_no_stop = dict(fdist_common_comment_words_no_stop.most_common(20)).values()
x_reply_word_no_stop = dict(fdist_common_reply_words_no_stop.most_common(20)).keys()
y_reply_word_count_no_stop = dict(fdist_common_reply_words_no_stop.most_common(20)).values()
ax3[0].bar(x_comment_word_no_stop, y_comment_word_count_no_stop)
ax3[0].tick_params('x', rotation = 90)
ax3[0].set_title('Comments')
ax3[1].bar(x_reply_word_no_stop, y_reply_word_count_no_stop)
ax3[1].tick_params('x', rotation = 90)
ax3[1].set_title('Replies')
ax3[0].set_ylabel('Count')
fig3.suptitle('Word Count without Stop Words')
plt.show()

# %% [markdown]
# To further process our dataset, we will lemmatize the words into their root form using NLTK's WordNet Lemmatizer. Before that, we will tag the words using parts of speech labels (POS). These POS tags will then be converted into a format the lemmatizer could read and use.

# %%
# Tagging our words with parts of speed
df['Comment with tag'] = df['Tokenized Comment'].apply(nltk.tag.pos_tag)
df['Reply with tag'] = df['Tokenized Reply'].apply(nltk.tag.pos_tag)
df['Comment_no_sw with tag'] = df['Tokenized Comment_no_sw'].apply(nltk.tag.pos_tag)
df['Reply_no_sw with tag'] = df['Tokenized Reply_no_sw'].apply(nltk.tag.pos_tag)
df
# Out:
#                                                   Comment  \
# 0       Can we make this quick? Roxanne Korrine and An...
# 1       Well, I thought we'd start with pronunciation,...
# 2       Not the hacking and gagging and spitting part ...
# 3       You're asking me out That's so cute What's you...
# 4       No, no, it's my fault - we didn't have a prope...
# ...                                                   ...
# 214681                           Your orders, Mr Vereker?
# 214682  I'm to take the Sikali with the main column to...
# 214683  Lord Chelmsford seems to want me to stay back ...
# 214684  Well I assure you, Sir, I have no desire to cr...
# 214685  And I assure you, you do not In fact I'd be ob...
#
#                                                     Reply  \
# 0       Well, I thought we'd start with pronunciation,...
# 1       Not the hacking and gagging and spitting part ...
# 2       Okay then how 'bout we try out some French cui...
# ...

# %%
# Defining function to convert our POS tags into WordNet format
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
# Convert tags into WordNet POS format
df['Comment with WordNet'] = df['Comment with tag'].apply(lambda x: [(word, get_wordnet_pos(pos_tag)) for (word, pos_tag) in x])
df['Reply with WordNet'] = df['Reply with tag'].apply(lambda x: [(word, get_wordnet_pos(pos_tag)) for (word, pos_tag) in x])
df['Comment_no_sw with WordNet'] = df['Comment_no_sw with tag'].apply(lambda x: [(word, get_wordnet_pos(pos_tag)) for (word, pos_tag) in x])
df['Reply_no_sw with WordNet'] = df['Reply_no_sw with tag'].apply(lambda x: [(word, get_wordnet_pos(pos_tag)) for (word, pos_tag) in x])
df
# Out:
#                                                   Comment  \
# 0       Can we make this quick? Roxanne Korrine and An...
# 1       Well, I thought we'd start with pronunciation,...
# 2       Not the hacking and gagging and spitting part ...
# 3       You're asking me out That's so cute What's you...
# 4       No, no, it's my fault - we didn't have a prope...
# ...                                                   ...
# 214681                           Your orders, Mr Vereker?
# 214682  I'm to take the Sikali with the main column to...
# 214683  Lord Chelmsford seems to want me to stay back ...
# 214684  Well I assure you, Sir, I have no desire to cr...
# 214685  And I assure you, you do not In fact I'd be ob...
#
#                                                     Reply  \
# 0       Well, I thought we'd start with pronunciation,...
# 1       Not the hacking and gagging and spitting part ...
# 2       Okay then how 'bout we try out some French cui...
# ...

# %%
# Lemmatize our tagged comments and replies
wordnet_lemmatizer = WordNetLemmatizer()
df['Lemmatized Comment'] = df['Comment with WordNet'].apply(lambda x: [wordnet_lemmatizer.lemmatize(word, tag) for (word, tag) in x])
df['Lemmatized Reply'] = df['Reply with WordNet'].apply(lambda x: [wordnet_lemmatizer.lemmatize(word, tag) for (word, tag) in x])
df['Lemmatized Comment_no_sw'] = df['Comment_no_sw with WordNet'].apply(lambda x: [wordnet_lemmatizer.lemmatize(word, tag) for (word, tag) in x])
df['Lemmatized Reply_no_sw'] = df['Reply_no_sw with WordNet'].apply(lambda x: [wordnet_lemmatizer.lemmatize(word, tag) for (word, tag) in x])
df
# Out:
#                                                   Comment  \
# 0       Can we make this quick? Roxanne Korrine and An...
# 1       Well, I thought we'd start with pronunciation,...
# 2       Not the hacking and gagging and spitting part ...
# 3       You're asking me out That's so cute What's you...
# 4       No, no, it's my fault - we didn't have a prope...
# ...                                                   ...
# 214681                           Your orders, Mr Vereker?
# 214682  I'm to take the Sikali with the main column to...
# 214683  Lord Chelmsford seems to want me to stay back ...
# 214684  Well I assure you, Sir, I have no desire to cr...
# 214685  And I assure you, you do not In fact I'd be ob...
#
#                                                     Reply  \
# 0       Well, I thought we'd start with pronunciation,...
# 1       Not the hacking and gagging and spitting part ...
# 2       Okay then how 'bout we try out some French cui...
# ...

# %% [markdown]
# We could check on it the frequency of the data again now that everything has been lemmatized.

# %%
all_words_comments_lemmatized = list(itertools.chain.from_iterable(df['Lemmatized Comment'][:]))
all_words_replies_lemmatized = list(itertools.chain.from_iterable(df['Lemmatized Reply'][:]))
all_words_comments_lemmatized_no_sw = list(itertools.chain.from_iterable(df['Lemmatized Comment_no_sw'][:]))
all_words_replies_lemmatized_no_sw = list(itertools.chain.from_iterable(df['Lemmatized Reply_no_sw'][:]))

# %%
fdist_common_comment_words_lemmatized = FreqDist(all_words_comments_lemmatized)
fdist_common_comment_words_lemmatized.most_common(20)
# Out:
# [('be', 130854),
#  ('you', 100296),
#  ('i', 88262),
#  ('the', 60414),
#  ('to', 54754),
#  ('do', 47618),
#  ('a', 47326),
#  ('not', 46632),
#  ('it', 41459),
#  ('that', 29341),
#  ('have', 28811),
#  ('what', 27842),
#  ('and', 25679),
#  ('of', 23866),
#  ('in', 20845),
#  ('me', 20427),
#  ('get', 18707),
#  ('we', 18346),
#  ('go', 16817),
#  ('he', 16751)]

# %%
fdist_common_reply_words_lemmatized = FreqDist(all_words_replies_lemmatized)
fdist_common_reply_words_lemmatized.most_common(20)
# Out:
# [('be', 130708),
#  ('i', 95757),
#  ('you', 95366),
#  ('the', 60823),
#  ('to', 55505),
#  ('not', 50307),
#  ('a', 49258),
#  ('do', 46906),
#  ('it', 44530),
#  ('that', 30265),
#  ('have', 28849),
#  ('and', 27500),
#  ('of', 24662),
#  ('what', 24008),
#  ('in', 21444),
#  ('me', 21147),
#  ('get', 19152),
#  ('we', 18419),
#  ('he', 17665),
#  ('know', 16904)]

# %%
fdist_common_comment_words_lemmatized_no_sw = FreqDist(all_words_comments_lemmatized_no_sw)
fdist_common_comment_words_lemmatized_no_sw.most_common(20)
# Out:
# [('get', 18430),
#  ('go', 16817),
#  ('know', 15440),
#  ('like', 9913),
#  ('want', 9684),
#  ('would', 9383),
#  ('think', 9157),
#  ('say', 8180),
#  ('well', 7187),
#  ('one', 6768),
#  ('come', 6558),
#  ('tell', 6361),
#  ('see', 6284),
#  ('right', 6050),
#  ('look', 5483),
#  ('take', 5179),
#  ('oh', 5104),
#  ('make', 5060),
#  ('good', 5020),
#  ('u', 5011)]

# %%
fdist_common_reply_words_lemmatized_no_sw = FreqDist(all_words_replies_lemmatized_no_sw)
fdist_common_reply_words_lemmatized_no_sw.most_common(20)
# Out:
# [('get', 18893),
#  ('know', 16508),
#  ('go', 16434),
#  ('like', 10056),
#  ('want', 9712),
#  ('would', 9566),
#  ('think', 9177),
#  ('well', 8215),
#  ('say', 8198),
#  ('one', 7073),
#  ('right', 6932),
#  ('come', 6680),
#  ('see', 6520),
#  ('tell', 6311),
#  ('yes', 6155),
#  ('yeah', 5792),
#  ('oh', 5705),
#  ('good', 5531),
#  ('look', 5492),
#  ('take', 5373)]

# %%
# Plotting the top 20 words for both comments and replies after lemmatizing
fig4, ax4 = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
x_comment_word_lemmatized = dict(fdist_common_comment_words_lemmatized.most_common(20)).keys()
y_comment_word_count_lemmatized = dict(fdist_common_comment_words_lemmatized.most_common(20)).values()
x_reply_word_lemmatized = dict(fdist_common_reply_words_lemmatized.most_common(20)).keys()
y_reply_word_count_lemmatized = dict(fdist_common_reply_words_lemmatized.most_common(20)).values()
ax4[0].bar(x_comment_word_lemmatized, y_comment_word_count_lemmatized)
ax4[0].tick_params('x', rotation = 90)
ax4[0].set_title('Comments')
ax4[1].bar(x_reply_word_lemmatized, y_reply_word_count_lemmatized)
ax4[1].tick_params('x', rotation = 90)
ax4[1].set_title('Replies')
ax4[0].set_ylabel('Count')
fig4.suptitle('Word Count Lemmatized with Stop-words')
plt.show()

# %%
# Plotting the top 20 words for both comments and replies after lemmatizing
fig5, ax5 = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
x_comment_word_lemmatized_no_sw = dict(fdist_common_comment_words_lemmatized_no_sw.most_common(20)).keys()
y_comment_word_count_lemmatized_no_sw = dict(fdist_common_comment_words_lemmatized_no_sw.most_common(20)).values()
x_reply_word_lemmatized_no_sw = dict(fdist_common_reply_words_lemmatized_no_sw.most_common(20)).keys()
y_reply_word_count_lemmatized_no_sw = dict(fdist_common_reply_words_lemmatized_no_sw.most_common(20)).values()
ax5[0].bar(x_comment_word_lemmatized_no_sw, y_comment_word_count_lemmatized_no_sw)
ax5[0].tick_params('x', rotation = 90)
ax5[0].set_title('Comments')
ax5[1].bar(x_reply_word_lemmatized_no_sw, y_reply_word_count_lemmatized_no_sw)
ax5[1].tick_params('x', rotation = 90)
ax5[1].set_title('Replies')
ax5[0].set_ylabel('Count')
fig5.suptitle('Word Count Lemmatized without Stop-words')
plt.show()

# %% [markdown]
# The letter 'u' appears pretty often in the comments without stop-words (5011 times), which is strange. What is going on? Apparently there an issue with NLTK's wordnet lemmatizer (see link: https://stackoverflow.com/questions/54784287/nltk-wordnetlemmatizer-processes-us-as-u). To deal with the 'u'/'us' issue, we will use an if/else statment for the word 'us'. We'll do this for both with and without stop-words.

# %%
# Lemmatize our tagged comments and replies (an if statement is used for the word 'us')
df['Lemmatized Comment New'] = df['Comment with WordNet'].apply(lambda x: [wordnet_lemmatizer.lemmatize(word, tag) if word != 'us' else word for (word, tag) in x])
df['Lemmatized Reply New'] = df['Reply with WordNet'].apply(lambda x: [wordnet_lemmatizer.lemmatize(word, tag) if word != 'us' else word for (word, tag) in x])
df['Lemmatized Comment_no_sw New'] = df['Comment_no_sw with WordNet'].apply(lambda x: [wordnet_lemmatizer.lemmatize(word, tag) if word != 'us' else word for (word, tag) in x])
df['Lemmatized Reply_no_sw New'] = df['Reply_no_sw with WordNet'].apply(lambda x: [wordnet_lemmatizer.lemmatize(word, tag) if word != 'us' else word for (word, tag) in x])

# %% [markdown]
# Here, we'll just check if the problem still exist in our comments without stop-words.

# %%
all_words_comments_lemmatized2_no_sw = list(itertools.chain.from_iterable(df['Lemmatized Comment_no_sw New'][:]))
all_words_replies_lemmatized2_no_sw = list(itertools.chain.from_iterable(df['Lemmatized Reply_no_sw New'][:]))

# %%
fdist_common_comment_words_lemmatized2_no_sw = FreqDist(all_words_comments_lemmatized2_no_sw)
fdist_common_comment_words_lemmatized2_no_sw.most_common(20)
# Out:
# [('get', 18430),
#  ('go', 16817),
#  ('know', 15440),
#  ('like', 9913),
#  ('want', 9684),
#  ('would', 9383),
#  ('think', 9157),
#  ('say', 8180),
#  ('well', 7187),
#  ('one', 6768),
#  ('come', 6558),
#  ('tell', 6361),
#  ('see', 6284),
#  ('right', 6050),
#  ('look', 5483),
#  ('take', 5179),
#  ('oh', 5104),
#  ('make', 5060),
#  ('good', 5020),
#  ('us', 4993)]

# %%
fdist_common_reply_words_lemmatized2_no_sw = FreqDist(all_words_replies_lemmatized2_no_sw)
fdist_common_reply_words_lemmatized2_no_sw.most_common(20)
# Out:
# [('get', 18893),
#  ('know', 16508),
#  ('go', 16434),
#  ('like', 10056),
#  ('want', 9712),
#  ('would', 9566),
#  ('think', 9177),
#  ('well', 8215),
#  ('say', 8198),
#  ('one', 7073),
#  ('right', 6932),
#  ('come', 6680),
#  ('see', 6520),
#  ('tell', 6311),
#  ('yes', 6155),
#  ('yeah', 5792),
#  ('oh', 5705),
#  ('good', 5531),
#  ('look', 5492),
#  ('take', 5373)]

# %%
# Plotting the top 20 words for both comments and replies after lemmatizing
fig6, ax6 = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
x_comment_word_lemmatized2_no_sw = dict(fdist_common_comment_words_lemmatized2_no_sw.most_common(20)).keys()
y_comment_word_count_lemmatized2_no_sw = dict(fdist_common_comment_words_lemmatized2_no_sw.most_common(20)).values()
x_reply_word_lemmatized2_no_sw = dict(fdist_common_reply_words_lemmatized2_no_sw.most_common(20)).keys()
y_reply_word_count_lemmatized2_no_sw = dict(fdist_common_reply_words_lemmatized2_no_sw.most_common(20)).values()
ax6[0].bar(x_comment_word_lemmatized2_no_sw, y_comment_word_count_lemmatized2_no_sw)
ax6[0].tick_params('x', rotation = 90)
ax6[0].set_title('Comments')
ax6[1].bar(x_reply_word_lemmatized2_no_sw, y_reply_word_count_lemmatized2_no_sw)
ax6[1].tick_params('x', rotation = 90)
ax6[1].set_title('Replies')
ax6[0].set_ylabel('Count')
fig6.suptitle('Word Count Lemmatized without Stop-words')
plt.show()

# %%
# Checking all columns if there are still any stray 'u'
list_of_comments = []
for i, comment in enumerate(df['Lemmatized Comment New']):
    if 'u' in comment:
        list_of_comments.append(df['Lemmatized Comment New'][i])
print(list_of_comments)
# Out:
# [['i', 'think', 'we', 'decide', 'you', 'be', 'go', 'to', 'school', 'here', 'at', 'u', 'of', '0'], ['catch', 'some', 'son', 'of', 'a', 'bitch', 'steal', 'my', 'bike', 'use', 'a', 'car', 'jack', 'to', 'blow', 'out', 'my', 'u', 'lock', 'and', 'bend', 'a', 'bunch', 'of', 'spoke', 'so', 'now', 'i', 'get', 'to', 'get', 'my', 'wheel', 'fix'], ['u', 'what', 'do', 'you', 'think'], ['it', 'be', 'an', 'anagram', 'it', 'come', 'from', 'the', 'canon', 'of', 'dort', 'every', 'letter', 'stand', 'for', 'a', 'different', 'belief', 't', 'u', 'l', 'i', 'p', 'like', 'be', 'you', 'sure', 'you', 'be', 'interested', 'in', 'this'], ['be', 'that', 'a', 'it', 'may', 'u', 'be', 'for', 'unconditional', 'election', 'god', 'have', 'choose', 'a', 'certain', 'number', 'of', 'people', 'to', 'be', 'save', 'the', 'elect', 'and', 'he', 'have', 'choose', 'them', 'from', 'the', 'beginning', 'of', 'time', 'l', 'be', 'for', 'limited', 'atonement', 'only', 'a', 'limited', 'number', 'will', 'be', 'atone', 'will', 'go', 'to',
# ...

# %% [markdown]
# The if/else does appear to have fixed most, if not all, of the problems (4993 out of 5011). Some of them appears to be used in the context of a noun (i.e. at u of 0, where u is a name) or it's part of a different problem during lemmatization (i.e. u lock, which should originally be part of the word u-lock, s u n n y, of which u is part of the word sunny, or u what, where u should have been you). We'll leave these alone for now. But could come back to it if need be.

# %% [markdown]
# Given we have processed and removed so many words, we should check to see if there are any empty comments and replies. Before that however, we'll tidy up our DataFrame. The new columns will replace the old lemmatized columns.

# %%
# Dropping the old 'Lemmatized Comment_no_sw' and 'Lemmatized Reply_no_sw' columns
df = df.drop(columns=['Lemmatized Comment_no_sw', 'Lemmatized Reply_no_sw',
                      'Lemmatized Comment', 'Lemmatized Reply'], axis=1)

# %%
df['Lem Comment Length'] = df['Lemmatized Comment New'].apply(len)
df['Lem Reply Length'] = df['Lemmatized Reply New'].apply(len)
df['Lem Comment_no_sw Length'] = df['Lemmatized Comment_no_sw New'].apply(len)
df['Lem Reply_no_sw Length'] = df['Lemmatized Reply_no_sw New'].apply(len)

# Renaming the new columns to 'Lemmatized Comment_no_sw' and 'Lemmatized Reply_no_sw'
df = df.rename({'Lemmatized Comment_no_sw New':'Lemmatized Comment_no_sw', 
                'Lemmatized Reply_no_sw New':'Lemmatized Reply_no_sw',
                'Lemmatized Comment New':'Lemmatized Comment',
                'Lemmatized Reply New':'Lemmatized Reply'}, axis=1)
df
# Out:
#                                                   Comment  \
# 0       Can we make this quick? Roxanne Korrine and An...
# 1       Well, I thought we'd start with pronunciation,...
# 2       Not the hacking and gagging and spitting part ...
# 3       You're asking me out That's so cute What's you...
# 4       No, no, it's my fault - we didn't have a prope...
# ...                                                   ...
# 214681                           Your orders, Mr Vereker?
# 214682  I'm to take the Sikali with the main column to...
# 214683  Lord Chelmsford seems to want me to stay back ...
# 214684  Well I assure you, Sir, I have no desire to cr...
# 214685  And I assure you, you do not In fact I'd be ob...
#
#                                                     Reply  \
# 0       Well, I thought we'd start with pronunciation,...
# 1       Not the hacking and gagging and spitting part ...
# 2       Okay then how 'bout we try out some French cui...
# ...

# %% [markdown]
# Now to checking and clean up any rows with empty comments or replies.

# %%
# Checking the length of processed comments and replies
df[df['Lem Comment_no_sw Length'] == 0].count()
# Out:
# Comment                       12018
# Reply                         12018
# Expanded Comment              12018
# Expanded Reply                12018
# Comment Length                12018
# Reply Length                  12018
# Tokenized Comment             12018
# Tokenized Reply               12018
# Tokenized Comment_no_sw       12018
# Tokenized Reply_no_sw         12018
# Comment with tag              12018
# Reply with tag                12018
# Comment_no_sw with tag        12018
# Reply_no_sw with tag          12018
# Comment with WordNet          12018
# Reply with WordNet            12018
# Comment_no_sw with WordNet    12018
# Reply_no_sw with WordNet      12018
# Lemmatized Comment            12018
# Lemmatized Reply              12018
# Lemmatized Comment_no_sw      12018
# Lemmatized Reply_no_sw        12018
# Lem Comment Length            12018
# Lem Reply Length              12018
# Lem Comment_no_sw Length      12018
# Lem Reply_no_sw Length        12018
# ...

# %%
df[df['Lem Reply_no_sw Length'] == 0].count()
# Out:
# Comment                       11432
# Reply                         11432
# Expanded Comment              11432
# Expanded Reply                11432
# Comment Length                11432
# Reply Length                  11432
# Tokenized Comment             11432
# Tokenized Reply               11432
# Tokenized Comment_no_sw       11432
# Tokenized Reply_no_sw         11432
# Comment with tag              11432
# Reply with tag                11432
# Comment_no_sw with tag        11432
# Reply_no_sw with tag          11432
# Comment with WordNet          11432
# Reply with WordNet            11432
# Comment_no_sw with WordNet    11432
# Reply_no_sw with WordNet      11432
# Lemmatized Comment            11432
# Lemmatized Reply              11432
# Lemmatized Comment_no_sw      11432
# Lemmatized Reply_no_sw        11432
# Lem Comment Length            11432
# Lem Reply Length              11432
# Lem Comment_no_sw Length      11432
# Lem Reply_no_sw Length        11432
# ...

# %%
df[df['Lem Comment Length'] == 0].count()
# Out:
# Comment                       0
# Reply                         0
# Expanded Comment              0
# Expanded Reply                0
# Comment Length                0
# Reply Length                  0
# Tokenized Comment             0
# Tokenized Reply               0
# Tokenized Comment_no_sw       0
# Tokenized Reply_no_sw         0
# Comment with tag              0
# Reply with tag                0
# Comment_no_sw with tag        0
# Reply_no_sw with tag          0
# Comment with WordNet          0
# Reply with WordNet            0
# Comment_no_sw with WordNet    0
# Reply_no_sw with WordNet      0
# Lemmatized Comment            0
# Lemmatized Reply              0
# Lemmatized Comment_no_sw      0
# Lemmatized Reply_no_sw        0
# Lem Comment Length            0
# Lem Reply Length              0
# Lem Comment_no_sw Length      0
# Lem Reply_no_sw Length        0
# dtype: int64

# %%
df[df['Lem Reply Length'] == 0].count()
# Out:
# Comment                       0
# Reply                         0
# Expanded Comment              0
# Expanded Reply                0
# Comment Length                0
# Reply Length                  0
# Tokenized Comment             0
# Tokenized Reply               0
# Tokenized Comment_no_sw       0
# Tokenized Reply_no_sw         0
# Comment with tag              0
# Reply with tag                0
# Comment_no_sw with tag        0
# Reply_no_sw with tag          0
# Comment with WordNet          0
# Reply with WordNet            0
# Comment_no_sw with WordNet    0
# Reply_no_sw with WordNet      0
# Lemmatized Comment            0
# Lemmatized Reply              0
# Lemmatized Comment_no_sw      0
# Lemmatized Reply_no_sw        0
# Lem Comment Length            0
# Lem Reply Length              0
# Lem Comment_no_sw Length      0
# Lem Reply_no_sw Length        0
# dtype: int64

# %% [markdown]
# There is quite a bit of empty responses from the lines without stop-words. As we need comments and replies as pairs, these empty responses is of no value to us. We will remove these rows using Pandas' .drop() function.

# %%
# Dropping rows with processed comments and replies that ends up empty
df = df.drop(df[df['Lem Comment_no_sw Length'] == 0].index)
df = df.drop(df[df['Lem Reply_no_sw Length'] == 0].index)

# %%
df[df['Lem Comment_no_sw Length'] == 0].count()
# Out:
# Comment                       0
# Reply                         0
# Expanded Comment              0
# Expanded Reply                0
# Comment Length                0
# Reply Length                  0
# Tokenized Comment             0
# Tokenized Reply               0
# Tokenized Comment_no_sw       0
# Tokenized Reply_no_sw         0
# Comment with tag              0
# Reply with tag                0
# Comment_no_sw with tag        0
# Reply_no_sw with tag          0
# Comment with WordNet          0
# Reply with WordNet            0
# Comment_no_sw with WordNet    0
# Reply_no_sw with WordNet      0
# Lemmatized Comment            0
# Lemmatized Reply              0
# Lemmatized Comment_no_sw      0
# Lemmatized Reply_no_sw        0
# Lem Comment Length            0
# Lem Reply Length              0
# Lem Comment_no_sw Length      0
# Lem Reply_no_sw Length        0
# dtype: int64

# %%
df[df['Lem Reply_no_sw Length'] == 0].count()
# Out:
# Comment                       0
# Reply                         0
# Expanded Comment              0
# Expanded Reply                0
# Comment Length                0
# Reply Length                  0
# Tokenized Comment             0
# Tokenized Reply               0
# Tokenized Comment_no_sw       0
# Tokenized Reply_no_sw         0
# Comment with tag              0
# Reply with tag                0
# Comment_no_sw with tag        0
# Reply_no_sw with tag          0
# Comment with WordNet          0
# Reply with WordNet            0
# Comment_no_sw with WordNet    0
# Reply_no_sw with WordNet      0
# Lemmatized Comment            0
# Lemmatized Reply              0
# Lemmatized Comment_no_sw      0
# Lemmatized Reply_no_sw        0
# Lem Comment Length            0
# Lem Reply Length              0
# Lem Comment_no_sw Length      0
# Lem Reply_no_sw Length        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 191928 entries, 0 to 214685
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Comment                     191928 non-null  object
#  1   Reply                       191928 non-null  object
#  2   Expanded Comment            191928 non-null  object
#  3   Expanded Reply              191928 non-null  object
#  4   Comment Length              191928 non-null  int64
#  5   Reply Length                191928 non-null  int64
#  6   Tokenized Comment           191928 non-null  object
#  7   Tokenized Reply             191928 non-null  object
#  8   Tokenized Comment_no_sw     191928 non-null  object
#  9   Tokenized Reply_no_sw       191928 non-null  object
#  10  Comment with tag            191928 non-null  object
#  11  Reply with tag              191928 non-null  object
#  12  Comment_no_sw with tag      191928 non-null  object
# ...

# %%
all_words_comments_lemmatized3 = list(itertools.chain.from_iterable(df['Lemmatized Comment'][:]))
all_words_replies_lemmatized3 = list(itertools.chain.from_iterable(df['Lemmatized Reply'][:]))
all_words_comments_lemmatized3_no_sw = list(itertools.chain.from_iterable(df['Lemmatized Comment_no_sw'][:]))
all_words_replies_lemmatized3_no_sw = list(itertools.chain.from_iterable(df['Lemmatized Reply_no_sw'][:]))

# %%
fdist_common_comment_words_lemmatized3 = FreqDist(all_words_comments_lemmatized3)
fdist_common_comment_words_lemmatized3.most_common(20)
# Out:
# [('be', 120786),
#  ('you', 92847),
#  ('i', 82330),
#  ('the', 57574),
#  ('to', 51583),
#  ('a', 44995),
#  ('do', 42936),
#  ('not', 42934),
#  ('it', 38174),
#  ('that', 27105),
#  ('have', 26906),
#  ('and', 24164),
#  ('of', 22723),
#  ('what', 22709),
#  ('in', 19802),
#  ('me', 18909),
#  ('get', 17745),
#  ('we', 17225),
#  ('go', 15880),
#  ('he', 15436)]

# %%
fdist_common_reply_words_lemmatized3 = FreqDist(all_words_replies_lemmatized3)
fdist_common_reply_words_lemmatized3.most_common(20)
# Out:
# [('be', 120622),
#  ('i', 89088),
#  ('you', 88397),
#  ('the', 56840),
#  ('to', 51857),
#  ('a', 46320),
#  ('not', 46243),
#  ('do', 42574),
#  ('it', 40968),
#  ('that', 28153),
#  ('have', 26863),
#  ('and', 25565),
#  ('of', 23090),
#  ('in', 20026),
#  ('what', 19726),
#  ('me', 19470),
#  ('get', 18058),
#  ('we', 17139),
#  ('he', 16159),
#  ('know', 15828)]

# %%
fdist_common_comment_words_lemmatized3_no_sw = FreqDist(all_words_comments_lemmatized3_no_sw)
fdist_common_comment_words_lemmatized3_no_sw.most_common(20)
# Out:
# [('get', 17483),
#  ('go', 15880),
#  ('know', 14559),
#  ('like', 9455),
#  ('want', 9076),
#  ('would', 8926),
#  ('think', 8623),
#  ('say', 7764),
#  ('well', 6858),
#  ('one', 6377),
#  ('come', 6216),
#  ('tell', 5973),
#  ('see', 5920),
#  ('right', 5778),
#  ('look', 5186),
#  ('take', 4868),
#  ('oh', 4854),
#  ('make', 4811),
#  ('good', 4806),
#  ('us', 4769)]

# %%
fdist_common_reply_words_lemmatized3_no_sw = FreqDist(all_words_replies_lemmatized3_no_sw)
fdist_common_reply_words_lemmatized3_no_sw.most_common(20)
# Out:
# [('get', 17818),
#  ('go', 15453),
#  ('know', 15452),
#  ('like', 9464),
#  ('want', 9109),
#  ('would', 9078),
#  ('think', 8640),
#  ('well', 7760),
#  ('say', 7667),
#  ('one', 6623),
#  ('right', 6604),
#  ('come', 6278),
#  ('see', 6149),
#  ('tell', 5923),
#  ('yes', 5883),
#  ('yeah', 5642),
#  ('oh', 5488),
#  ('good', 5270),
#  ('look', 5148),
#  ('take', 5029)]

# %%
# Plotting the top 20 words for both comments and replies after lemmatizing and removing empty responses
fig7, ax7 = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
x_comment_word_lemmatized3 = dict(fdist_common_comment_words_lemmatized3.most_common(20)).keys()
y_comment_word_count_lemmatized3 = dict(fdist_common_comment_words_lemmatized3.most_common(20)).values()
x_reply_word_lemmatized3 = dict(fdist_common_reply_words_lemmatized3.most_common(20)).keys()
y_reply_word_count_lemmatized3 = dict(fdist_common_reply_words_lemmatized3.most_common(20)).values()
ax7[0].bar(x_comment_word_lemmatized3, y_comment_word_count_lemmatized3)
ax7[0].tick_params('x', rotation = 90)
ax7[0].set_title('Comments')
ax7[1].bar(x_reply_word_lemmatized3, y_reply_word_count_lemmatized3)
ax7[1].tick_params('x', rotation = 90)
ax7[1].set_title('Replies')
ax7[0].set_ylabel('Count')
fig7.suptitle('Word Count Lemmatized with Stop-words')
plt.show()

# %%
# Plotting the top 20 words for both comments and replies after lemmatizing and removing empty responses
fig8, ax8 = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
x_comment_word_lemmatized3_no_sw = dict(fdist_common_comment_words_lemmatized3_no_sw.most_common(20)).keys()
y_comment_word_count_lemmatized3_no_sw = dict(fdist_common_comment_words_lemmatized3_no_sw.most_common(20)).values()
x_reply_word_lemmatized3_no_sw = dict(fdist_common_reply_words_lemmatized3_no_sw.most_common(20)).keys()
y_reply_word_count_lemmatized3_no_sw = dict(fdist_common_reply_words_lemmatized3_no_sw.most_common(20)).values()
ax8[0].bar(x_comment_word_lemmatized3_no_sw, y_comment_word_count_lemmatized3_no_sw)
ax8[0].tick_params('x', rotation = 90)
ax8[0].set_title('Comments')
ax8[1].bar(x_reply_word_lemmatized3_no_sw, y_reply_word_count_lemmatized3_no_sw)
ax8[1].tick_params('x', rotation = 90)
ax8[1].set_title('Replies')
ax8[0].set_ylabel('Count')
fig8.suptitle('Word Count Lemmatized without Stop-words')
plt.show()

# %%
df
# Out:
#                                                   Comment  \
# 0       Can we make this quick? Roxanne Korrine and An...
# 1       Well, I thought we'd start with pronunciation,...
# 2       Not the hacking and gagging and spitting part ...
# 3       You're asking me out That's so cute What's you...
# 4       No, no, it's my fault - we didn't have a prope...
# ...                                                   ...
# 214681                           Your orders, Mr Vereker?
# 214682  I'm to take the Sikali with the main column to...
# 214683  Lord Chelmsford seems to want me to stay back ...
# 214684  Well I assure you, Sir, I have no desire to cr...
# 214685  And I assure you, you do not In fact I'd be ob...
#
#                                                     Reply  \
# 0       Well, I thought we'd start with pronunciation,...
# 1       Not the hacking and gagging and spitting part ...
# 2       Okay then how 'bout we try out some French cui...
# ...

# %% [markdown]
# There might still be issues within the dataset, but we could start analyzing the data using NLTK's sentiment analyzer. As a start, the sentiment scores could be used to help categorize 'postive' from 'negative' responses. These might be used as features when start use the data for training our chatbot.

# %%
# Sentiment Analysis
sid = SentimentIntensityAnalyzer()
df['Sentiment Comment'] = df['Lemmatized Comment'].apply(lambda x: sid.polarity_scores(' '.join(x)))
df['Sentiment Reply'] = df['Lemmatized Reply'].apply(lambda x: sid.polarity_scores(' '.join(x)))
df['Sentiment Comment_no_sw'] = df['Lemmatized Comment_no_sw'].apply(lambda x: sid.polarity_scores(' '.join(x)))
df['Sentiment Reply_no_sw'] = df['Lemmatized Reply_no_sw'].apply(lambda x: sid.polarity_scores(' '.join(x)))
df
# Out:
#                                                   Comment  \
# 0       Can we make this quick? Roxanne Korrine and An...
# 1       Well, I thought we'd start with pronunciation,...
# 2       Not the hacking and gagging and spitting part ...
# 3       You're asking me out That's so cute What's you...
# 4       No, no, it's my fault - we didn't have a prope...
# ...                                                   ...
# 214681                           Your orders, Mr Vereker?
# 214682  I'm to take the Sikali with the main column to...
# 214683  Lord Chelmsford seems to want me to stay back ...
# 214684  Well I assure you, Sir, I have no desire to cr...
# 214685  And I assure you, you do not In fact I'd be ob...
#
#                                                     Reply  \
# 0       Well, I thought we'd start with pronunciation,...
# 1       Not the hacking and gagging and spitting part ...
# 2       Okay then how 'bout we try out some French cui...
# ...

# %%
# Sentiment Analysis Compound Score
df['Sentiment Comment Compound Score'] = df['Sentiment Comment'].apply(lambda x: x['compound'])
df['Sentiment Reply Compound Score'] = df['Sentiment Reply'].apply(lambda x: x['compound'])
df['Sentiment Comment_no_sw Compound Score'] = df['Sentiment Comment_no_sw'].apply(lambda x: x['compound'])
df['Sentiment Reply_no_sw Compound Score'] = df['Sentiment Reply_no_sw'].apply(lambda x: x['compound'])
df
# Out:
#                                                   Comment  \
# 0       Can we make this quick? Roxanne Korrine and An...
# 1       Well, I thought we'd start with pronunciation,...
# 2       Not the hacking and gagging and spitting part ...
# 3       You're asking me out That's so cute What's you...
# 4       No, no, it's my fault - we didn't have a prope...
# ...                                                   ...
# 214681                           Your orders, Mr Vereker?
# 214682  I'm to take the Sikali with the main column to...
# 214683  Lord Chelmsford seems to want me to stay back ...
# 214684  Well I assure you, Sir, I have no desire to cr...
# 214685  And I assure you, you do not In fact I'd be ob...
#
#                                                     Reply  \
# 0       Well, I thought we'd start with pronunciation,...
# 1       Not the hacking and gagging and spitting part ...
# 2       Okay then how 'bout we try out some French cui...
# ...

# %%
# Categorize Sentiment Analysis Compound Score
df['Sentiment Comment Classification'] = df['Sentiment Comment Compound Score'].apply(lambda x: 'positive' if x>0 else ('negative' if x<0 else 'neutral'))
df['Sentiment Reply Classification'] = df['Sentiment Reply Compound Score'].apply(lambda x: 'positive' if x>0 else ('negative' if x<0 else 'neutral'))
df['Sentiment Comment_no_sw Classification'] = df['Sentiment Comment_no_sw Compound Score'].apply(lambda x: 'positive' if x>0 else ('negative' if x<0 else 'neutral'))
df['Sentiment Reply_no_sw Classification'] = df['Sentiment Reply_no_sw Compound Score'].apply(lambda x: 'positive' if x>0 else ('negative' if x<0 else 'neutral'))
df
# Out:
#                                                   Comment  \
# 0       Can we make this quick? Roxanne Korrine and An...
# 1       Well, I thought we'd start with pronunciation,...
# 2       Not the hacking and gagging and spitting part ...
# 3       You're asking me out That's so cute What's you...
# 4       No, no, it's my fault - we didn't have a prope...
# ...                                                   ...
# 214681                           Your orders, Mr Vereker?
# 214682  I'm to take the Sikali with the main column to...
# 214683  Lord Chelmsford seems to want me to stay back ...
# 214684  Well I assure you, Sir, I have no desire to cr...
# 214685  And I assure you, you do not In fact I'd be ob...
#
#                                                     Reply  \
# 0       Well, I thought we'd start with pronunciation,...
# 1       Not the hacking and gagging and spitting part ...
# 2       Okay then how 'bout we try out some French cui...
# ...

# %%
df['Sentiment Comment Compound Score'].hist(histtype='step', bins=20, label='sw')
df['Sentiment Comment_no_sw Compound Score'].hist(histtype='step', bins=20, label='no_sw')
plt.title('Sentiment Comment Compound Score')
plt.xlabel('Score')
plt.ylabel('Count')
plt.legend()
plt.show()

# %%
df['Sentiment Reply Compound Score'].hist(histtype='step', bins=20, label='sw')
df['Sentiment Reply_no_sw Compound Score'].hist(histtype='step', bins=20, label='no_sw')
plt.title('Sentiment Reply Compound Score')
plt.xlabel('Score')
plt.ylabel('Count')
plt.legend()
plt.show()

# %%
# Sentiment Analysis Compound Score Overall
df['Sentiment Score Overall'] = df['Sentiment Comment Compound Score'] + df['Sentiment Reply Compound Score']
df['Sentiment Score Overall Classification'] = df['Sentiment Score Overall'].apply(lambda x: 'positive' if x>0 else ('negative' if x<0 else 'neutral'))
df['Sentiment Score_no_sw Overall'] = df['Sentiment Comment_no_sw Compound Score'] + df['Sentiment Reply_no_sw Compound Score']
df['Sentiment Score_no_sw Overall Classification'] = df['Sentiment Score_no_sw Overall'].apply(lambda x: 'positive' if x>0 else ('negative' if x<0 else 'neutral'))
df
# Out:
#                                                   Comment  \
# 0       Can we make this quick? Roxanne Korrine and An...
# 1       Well, I thought we'd start with pronunciation,...
# 2       Not the hacking and gagging and spitting part ...
# 3       You're asking me out That's so cute What's you...
# 4       No, no, it's my fault - we didn't have a prope...
# ...                                                   ...
# 214681                           Your orders, Mr Vereker?
# 214682  I'm to take the Sikali with the main column to...
# 214683  Lord Chelmsford seems to want me to stay back ...
# 214684  Well I assure you, Sir, I have no desire to cr...
# 214685  And I assure you, you do not In fact I'd be ob...
#
#                                                     Reply  \
# 0       Well, I thought we'd start with pronunciation,...
# 1       Not the hacking and gagging and spitting part ...
# 2       Okay then how 'bout we try out some French cui...
# ...

# %%
df['Sentiment Score Overall'].hist(histtype='step', bins=20, label='sw')
df['Sentiment Score_no_sw Overall'].hist(histtype='step', bins=20, label='no_sw')
plt.title('Sentiment Score Overall')
plt.xlabel('Score')
plt.ylabel('Count')
plt.legend()
plt.show()

# %%
df['Sentiment Score Overall Classification'].hist(histtype='step', label='sw')
df['Sentiment Score_no_sw Overall Classification'].hist(histtype='step', label='no_sw')
plt.title('Sentiment Score Overall Classification')
plt.xlabel('Classification')
plt.ylabel('Count')
plt.legend()
plt.show()

# %% [markdown]
# Before we export the data further down our pipeline, let's see what's in our columns first. Any extraneous columns could be left out of the file.

# %%
list(df.columns)
# Out:
# ['Comment',
#  'Reply',
#  'Expanded Comment',
#  'Expanded Reply',
#  'Comment Length',
#  'Reply Length',
#  'Tokenized Comment',
#  'Tokenized Reply',
#  'Tokenized Comment_no_sw',
#  'Tokenized Reply_no_sw',
#  'Comment with tag',
#  'Reply with tag',
#  'Comment_no_sw with tag',
#  'Reply_no_sw with tag',
#  'Comment with WordNet',
#  'Reply with WordNet',
#  'Comment_no_sw with WordNet',
#  'Reply_no_sw with WordNet',
#  'Lemmatized Comment',
#  'Lemmatized Reply',
#  'Lemmatized Comment_no_sw',
#  'Lemmatized Reply_no_sw',
#  'Lem Comment Length',
#  'Lem Reply Length',
#  'Lem Comment_no_sw Length',
#  'Lem Reply_no_sw Length',
#  'Sentiment Comment',
#  'Sentiment Reply',
#  'Sentiment Comment_no_sw',
#  'Sentiment Reply_no_sw',
#  'Sentiment Comment Compound Score',
#  'Sentiment Reply Compound Score',
#  'Sentiment Comment_no_sw Compound Score',
#  'Sentiment Reply_no_sw Compound Score',
#  'Sentiment Comment Classification',
#  'Sentiment Reply Classification',
# ...

# %%
# Columns with tags are no longer needed post-processing
columns_to_drop = ['Comment with tag','Reply with tag','Comment_no_sw with tag','Reply_no_sw with tag',
                   'Comment with WordNet','Reply with WordNet','Comment_no_sw with WordNet','Reply_no_sw with WordNet']

df = df.drop(columns_to_drop, axis=1)
df
# Out:
#                                                   Comment  \
# 0       Can we make this quick? Roxanne Korrine and An...
# 1       Well, I thought we'd start with pronunciation,...
# 2       Not the hacking and gagging and spitting part ...
# 3       You're asking me out That's so cute What's you...
# 4       No, no, it's my fault - we didn't have a prope...
# ...                                                   ...
# 214681                           Your orders, Mr Vereker?
# 214682  I'm to take the Sikali with the main column to...
# 214683  Lord Chelmsford seems to want me to stay back ...
# 214684  Well I assure you, Sir, I have no desire to cr...
# 214685  And I assure you, you do not In fact I'd be ob...
#
#                                                     Reply  \
# 0       Well, I thought we'd start with pronunciation,...
# 1       Not the hacking and gagging and spitting part ...
# 2       Okay then how 'bout we try out some French cui...
# ...

# %%
# Classification of sentiment might be great for visualization, but can be derived directly from the scores
# We could drop these columns as well
columns_to_drop2 = ['Sentiment Comment Classification','Sentiment Reply Classification',
                    'Sentiment Comment_no_sw Classification', 'Sentiment Reply_no_sw Classification',
                    'Sentiment Score Overall Classification', 'Sentiment Score_no_sw Overall Classification']

df = df.drop(columns_to_drop2, axis=1)
df
# Out:
#                                                   Comment  \
# 0       Can we make this quick? Roxanne Korrine and An...
# 1       Well, I thought we'd start with pronunciation,...
# 2       Not the hacking and gagging and spitting part ...
# 3       You're asking me out That's so cute What's you...
# 4       No, no, it's my fault - we didn't have a prope...
# ...                                                   ...
# 214681                           Your orders, Mr Vereker?
# 214682  I'm to take the Sikali with the main column to...
# 214683  Lord Chelmsford seems to want me to stay back ...
# 214684  Well I assure you, Sir, I have no desire to cr...
# 214685  And I assure you, you do not In fact I'd be ob...
#
#                                                     Reply  \
# 0       Well, I thought we'd start with pronunciation,...
# 1       Not the hacking and gagging and spitting part ...
# 2       Okay then how 'bout we try out some French cui...
# ...

# %%
list(df.columns)
# Out:
# ['Comment',
#  'Reply',
#  'Expanded Comment',
#  'Expanded Reply',
#  'Comment Length',
#  'Reply Length',
#  'Tokenized Comment',
#  'Tokenized Reply',
#  'Tokenized Comment_no_sw',
#  'Tokenized Reply_no_sw',
#  'Lemmatized Comment',
#  'Lemmatized Reply',
#  'Lemmatized Comment_no_sw',
#  'Lemmatized Reply_no_sw',
#  'Lem Comment Length',
#  'Lem Reply Length',
#  'Lem Comment_no_sw Length',
#  'Lem Reply_no_sw Length',
#  'Sentiment Comment',
#  'Sentiment Reply',
#  'Sentiment Comment_no_sw',
#  'Sentiment Reply_no_sw',
#  'Sentiment Comment Compound Score',
#  'Sentiment Reply Compound Score',
#  'Sentiment Comment_no_sw Compound Score',
#  'Sentiment Reply_no_sw Compound Score',
#  'Sentiment Score Overall',
#  'Sentiment Score_no_sw Overall']

# %% [markdown]
# For now, we will export this data as a csv for further processing (something like bag of words or TD-IDF).

# %%
df.to_csv('processed_movie_dialogue_pairs.csv')
